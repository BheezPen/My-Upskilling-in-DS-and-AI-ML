# %%
# importing necessary liraries to handle my data.
import pandas as pd
import numpy as np
import requests
from io import StringIO
from io import BytesIO

# %%
# github_csv_url = "https://raw.githubusercontent.com/calebade/Hamoye_internship/main/Neural_craft_team/Subnational%20African%20Data_Aug.19.2013.csv"

# response = requests.get(github_csv_url)
# csv_data = response.text
# df = pd.read_csv(StringIO(csv_data))

# %%
github_url = "https://raw.githubusercontent.com/calebade/Hamoye_internship/main/Neural_craft_team/Subnational%20African%20Data_Aug.19.2013.xls"

response = requests.get(github_url)
data = response.content
df = pd.read_excel(BytesIO(data))

# %% [markdown]
# # Data cleaning and Exploration Phase

# %% [markdown]
# I used the excel file instead of the csv since the columns are properly labeled for the excel file

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#   Country name ISO code  ISO numeric code Subnational region name  \
# 0      Burundi      BDI               108                 Bubanza
# 1      Burundi      BDI               108        Bujumbura Mairie
# 2      Burundi      BDI               108         Bujumbura Rural
# 3      Burundi      BDI               108                  Bururi
# 4      Burundi      BDI               108                 Cankuzo
#
#    CCAPS subnational region ID  Year Data Source             Website  \
# 0                       108002  2011         DHS  www.measuredhs.com
# 1                       108003  2011         DHS  www.measuredhs.com
# 2                       108004  2011         DHS  www.measuredhs.com
# 3                       108005  2011         DHS  www.measuredhs.com
# 4                       108006  2011         DHS  www.measuredhs.com
#
#    Net primary attendance rate (%)  Primary NAR standard error  \
# 0                        62.212669                    1.541257
# 1                        75.802948                    1.635965
# 2                        62.212669                    1.541257
# 3                        66.308830                    1.372277
# 4                        61.176640                    1.455065
#
#    Primary NAR sample size  Gross primary attendance rate (%)  \
# 0                   1494.0                         102.472580
# 1                    718.0                         112.636269
# 2                   1494.0                         102.472580
# 3                   2036.0                         117.472328
# 4                   2213.0                         113.127411
#
#    Primary GAR standard error  Primary GAR sample size  \
# 0                    3.636928                   1494.0
# 1                    4.013371                    719.0
# 2                    3.636928                   1494.0
# 3                    2.735463                   2037.0
# 4                    3.140667                   2216.0
#
#    Net secondary attendance rate (%)  Secondary NAR standard error  \
# 0                           7.844529                      0.965101
# 1                          31.958845                      2.921502
# 2                           7.844529                      0.965101
# 3                          12.385633                      1.100727
# 4                           5.808361                      0.836916
#
#    Secondar NAR sample size  Gross secondary attendance rate (%)  \
# 0                     817.0                            28.771719
# 1                     563.0                            95.412285
# 2                     817.0                            28.771719
# 3                    1268.0                            45.576622
# 4                    1438.0                            22.297937
#
#    Secondary GAR standard error  Secondary GAR sample size  \
# 0                      2.819628                      818.0
# 1                      6.530486                      563.0
# 2                      2.819628                      818.0
# 3                      3.021638                     1275.0
# 4                      2.037364                     1443.0
#
#    Literacy rate (15 & over)  Literacy rate (15 & over) standard error  \
# 0                  57.797642                                  2.044328
# 1                  88.665176                                  1.183123
# 2                  57.797642                                  2.044328
# 3                  70.883629                                  1.587037
# 4                  65.920868                                  1.458440
#
#    Literacy rate (15 & over) size  Literacy rate (15-24)  \
# 0                          2144.0              68.016655
# 1                          2002.0              88.634804
# 2                          2144.0              68.016655
# 3                          3050.0              80.191780
# 4                          3608.0              72.943398
#
#    Literacy rate (15-24) standard error  Literacy rate (15-24) size  \
# 0                              2.748220                       878.0
# 1                              1.151576                       992.0
# 2                              2.748220                       878.0
# 3                              1.696627                      1335.0
# 4                              1.839964                      1528.0
#
#    Literacy rate (15-19)  Literacy rate (15-19) standard error  \
# 0              76.789223                              2.812953
# 1              86.679359                              1.827134
# 2              76.789223                              2.812953
# 3              83.989784                              1.838226
# 4              78.405777                              2.368593
#
#    Literacy rate (15-19) size  Literacy rate (25-49)  \
# 0                       487.0              50.576019
# 1                       513.0              88.821198
# 2                       487.0              50.576019
# 3                       793.0              63.528339
# 4                       834.0              60.234745
#
#    Literacy rate (25-49) standard error  Literacy rate (25-49) size  \
# 0                              2.023862                      1204.0
# 1                              1.796425                       942.0
# 2                              2.023862                      1204.0
# 3                              1.884106                      1616.0
# 4                              1.812829                      1951.0
#
#    Access to improved water (% of population)  \
# 0                                   64.524750
# 1                                   90.069534
# 2                                   64.524750
# 3                                   67.941315
# 4                                   78.772392
#
#    Improved Water (% of pop) standard error  \
# 0                                  4.098234
# 1                                  2.291323
# 2                                  4.098234
# 3                                  3.748927
# 4                                  2.694942
#
#    Improved Water (% of pop) sample size  \
# 0                                 7248.0
# 1                                 4752.0
# 2                                 7248.0
# 3                                 9731.0
# 4                                11487.0
#
#    Access to improved sanitation (% of population)  \
# 0                                        42.428234
# 1                                        86.296799
# 2                                        42.428234
# 3                                        55.417877
# 4                                        44.918869
#
#    Improved Sanitation (% of pop) standard error  \
# 0                                       5.014913
# 1                                       4.456155
# 2                                       5.014913
# 3                                       4.216816
# 4                                       3.165077
#
#    Improved Sanitation (% of pop) sample size  \
# 0                                      7248.0
# 1                                      4752.0
# 2                                      7248.0
# 3                                      9731.0
# 4                                     11487.0
#
#    Electricity in household (% of population)  \
# 0                                    2.635628
# 1                                   62.607437
# 2                                    2.635628
# 3                                    3.004243
# 4                                    2.468756
#
#    Electricity (% of pop) standard error  Electricity (% of pop) sample size  \
# 0                               0.943304                              7248.0
# 1                               6.168787                              4752.0
# 2                               0.943304                              7248.0
# 3                               0.774846                              9731.0
# 4                               0.734672                             11487.0
#
#    Radio in household (% of population)  Radio (% of pop) standard error  \
# 0                             55.748539                         2.021995
# 1                             80.243233                         2.606479
# 2                             55.748539                         2.021995
# 3                             56.422264                         1.242099
# 4                             56.779015                         1.442348
#
#    Radio (% of pop) sample size  Television in household (% of population)  \
# 0                        7248.0                                   1.855816
# 1                        4752.0                                  53.190296
# 2                        7248.0                                   1.855816
# 3                        9731.0                                   4.437777
# 4                       11487.0                                   1.720605
#
#    Television (% of pop) standard error  Television (% of pop) sample size  \
# 0                              0.639537                             7248.0
# 1                              5.902191                             4752.0
# 2                              0.639537                             7248.0
# 3                              2.226572                             9731.0
# 4                              0.525061                            11487.0
#
#    Radio and/or Television in household (% of population)  \
# 0                                          55.494587
# 1                                          81.972755
# 2                                          55.494587
# 3                                          56.785858
# 4                                          56.796986
#
#    Radio and/or TV (% of pop) standard error  \
# 0                                   2.013759
# 1                                   2.609640
# 2                                   2.013759
# 3                                   1.242379
# 4                                   1.442665
#
#    Radio and/or TV (% of pop) sample size  \
# 0                                  7248.0
# 1                                  4752.0
# 2                                  7248.0
# 3                                  9731.0
# 4                                 11487.0
#
#    Access to improved water (% of households)  \
# 0                                   64.727745
# 1                                   88.540581
# 2                                   64.727745
# 3                                   67.956390
# 4                                   77.699234
#
#    Improved Water (% of hh) standard error  \
# 0                                 4.048388
# 1                                 2.479091
# 2                                 4.048388
# 3                                 3.516714
# 4                                 2.894140
#
#    Improved Water (% of hh) sample size  \
# 0                                1441.0
# 1                                 912.0
# 2                                1441.0
# 3                                1921.0
# 4                                2405.0
#
#    Access to improved sanitation (% of households)  \
# 0                                        41.207016
# 1                                        85.660011
# 2                                        41.207016
# 3                                        54.182552
# 4                                        43.863773
#
#    Improved Sanitation (% of hh) standard error  \
# 0                                      4.939431
# 1                                      4.584234
# 2                                      4.939431
# 3                                      4.030688
# 4                                      3.031380
#
#    Improved Sanitation (% of hh) sample size  \
# 0                                     1441.0
# 1                                      912.0
# 2                                     1441.0
# 3                                     1921.0
# 4                                     2405.0
#
#    Electricity in household (% of households)  \
# 0                                    2.563438
# 1                                   57.100666
# 2                                    2.563438
# 3                                    2.655414
# 4                                    2.015260
#
#    Electricity (% of hh) standard error  Electricity (% of hh) sample size  \
# 0                              0.932698                             1441.0
# 1                              6.255036                              912.0
# 2                              0.932698                             1441.0
# 3                              0.686601                             1921.0
# 4                              0.615241                             2405.0
#
#    Radio in household (% of households)  Radio (% of hh) standard error  \
# 0                             50.203342                        1.984068
# 1                             75.303909                        2.757758
# 2                             50.203342                        1.984068
# 3                             51.190273                        1.153134
# 4                             51.336479                        1.450344
#
#    Radio (% of hh) sample size  Television in household (% of households)  \
# 0                       1441.0                                   1.656027
# 1                        912.0                                  44.327900
# 2                       1441.0                                   1.656027
# 3                       1921.0                                   3.321293
# 4                       2405.0                                   1.289977
#
#    Television (% of hh) standard error  Television (% of hh) sample size  \
# 0                             0.644799                            1441.0
# 1                             5.504890                             912.0
# 2                             0.644799                            1441.0
# 3                             1.444279                            1921.0
# 4                             0.369800                            2405.0
#
#    Radio and/or television in household (% of households)  \
# 0                                          49.767658
# 1                                          77.148560
# 2                                          49.767658
# 3                                          51.439995
# 4                                          51.364285
#
#    Radio and/or TV (% of hh) standard error  \
# 0                                  1.906297
# 1                                  2.845784
# 2                                  1.906297
# 3                                  1.158005
# 4                                  1.450414
#
#    Radio and/or TV (% of hh) sample size
# 0                                 1441.0
# 1                                  912.0
# 2                                 1441.0
# 3                                 1921.0
# 4                                 2405.0

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.shape
# Out:
# (471, 68)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 471 entries, 0 to 470
# Data columns (total 68 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Country name                                            471 non-null    object
#  1   ISO code                                                471 non-null    object
#  2   ISO numeric code                                        471 non-null    int64
#  3   Subnational region name                                 471 non-null    object
#  4   CCAPS subnational region ID                             471 non-null    int64
#  5   Year                                                    471 non-null    int64
#  6   Data Source                                             471 non-null    object
#  7   Website                                                 471 non-null    object
#  8   Net primary attendance rate (%)                         470 non-null    float64
#  9   Primary NAR standard error                              470 non-null    float64
#  10  Primary NAR sample size                                 470 non-null    float64
#  11  Gross primary attendance rate (%)                       470 non-null    float64
#  12  Primary GAR standard error                              470 non-null    float64
#  13  Primary GAR sample size                                 470 non-null    float64
#  14  Net secondary attendance rate (%)                       470 non-null    float64
#  15  Secondary NAR standard error                            470 non-null    float64
#  16  Secondar NAR sample size                                470 non-null    float64
#  17  Gross secondary attendance rate (%)                     470 non-null    float64
#  18  Secondary GAR standard error                            470 non-null    float64
#  19  Secondary GAR sample size                               470 non-null    float64
#  20  Literacy rate (15 & over)                               347 non-null    float64
#  21  Literacy rate (15 & over) standard error                347 non-null    float64
#  22  Literacy rate (15 & over) size                          347 non-null    float64
#  23  Literacy rate (15-24)                                   347 non-null    float64
#  24  Literacy rate (15-24) standard error                    347 non-null    float64
#  25  Literacy rate (15-24) size                              347 non-null    float64
#  26  Literacy rate (15-19)                                   347 non-null    float64
#  27  Literacy rate (15-19) standard error                    347 non-null    float64
#  28  Literacy rate (15-19) size                              347 non-null    float64
#  29  Literacy rate (25-49)                                   347 non-null    float64
#  30  Literacy rate (25-49) standard error                    347 non-null    float64
#  31  Literacy rate (25-49) size                              347 non-null    float64
#  32  Access to improved water (% of population)              470 non-null    float64
#  33  Improved Water (% of pop) standard error                470 non-null    float64
#  34  Improved Water (% of pop) sample size                   470 non-null    float64
#  35  Access to improved sanitation (% of population)         470 non-null    float64
#  36  Improved Sanitation (% of pop) standard error           470 non-null    float64
#  37  Improved Sanitation (% of pop) sample size              470 non-null    float64
#  38  Electricity in household (% of population)              449 non-null    float64
#  39  Electricity (% of pop) standard error                   449 non-null    float64
#  40  Electricity (% of pop) sample size                      449 non-null    float64
#  41  Radio in household (% of population)                    461 non-null    float64
#  42  Radio (% of pop) standard error                         461 non-null    float64
#  43  Radio (% of pop) sample size                            461 non-null    float64
#  44  Television in household (% of population)               461 non-null    float64
#  45  Television (% of pop) standard error                    461 non-null    float64
#  46  Television (% of pop) sample size                       461 non-null    float64
#  47  Radio and/or Television in household (% of population)  461 non-null    float64
#  48  Radio and/or TV (% of pop) standard error               461 non-null    float64
#  49  Radio and/or TV (% of pop) sample size                  461 non-null    float64
#  50  Access to improved water (% of households)              470 non-null    float64
#  51  Improved Water (% of hh) standard error                 470 non-null    float64
#  52  Improved Water (% of hh) sample size                    470 non-null    float64
#  53  Access to improved sanitation (% of households)         470 non-null    float64
#  54  Improved Sanitation (% of hh) standard error            470 non-null    float64
#  55  Improved Sanitation (% of hh) sample size               470 non-null    float64
#  56  Electricity in household (% of households)              449 non-null    float64
#  57  Electricity (% of hh) standard error                    449 non-null    float64
#  58  Electricity (% of hh) sample size                       449 non-null    float64
#  59  Radio in household (% of households)                    461 non-null    float64
#  60  Radio (% of hh) standard error                          461 non-null    float64
#  61  Radio (% of hh) sample size                             461 non-null    float64
#  62  Television in household (% of households)               461 non-null    float64
#  63  Television (% of hh) standard error                     461 non-null    float64
#  64  Television (% of hh) sample size                        461 non-null    float64
#  65  Radio and/or television in household (% of households)  461 non-null    float64
#  66  Radio and/or TV (% of hh) standard error                461 non-null    float64
#  67  Radio and/or TV (% of hh) sample size                   461 non-null    float64
# dtypes: float64(60), int64(3), object(5)
# memory usage: 250.3+ KB

# %%
pd.set_option('display.max_rows', None)
null_values = df.isnull().sum()

print("Columns with Null Values:")
print(null_values)
# Out:
# Columns with Null Values:
# Country name                                                0
# ISO code                                                    0
# ISO numeric code                                            0
# Subnational region name                                     0
# CCAPS subnational region ID                                 0
# Year                                                        0
# Data Source                                                 0
# Website                                                     0
# Net primary attendance rate (%)                             1
# Primary NAR standard error                                  1
# Primary NAR sample size                                     1
# Gross primary attendance rate (%)                           1
# Primary GAR standard error                                  1
# Primary GAR sample size                                     1
# Net secondary attendance rate (%)                           1
# Secondary NAR standard error                                1
# Secondar NAR sample size                                    1
# Gross secondary attendance rate (%)                         1
# Secondary GAR standard error                                1
# Secondary GAR sample size                                   1
# Literacy rate (15 & over)                                 124
# Literacy rate (15 & over) standard error                  124
# Literacy rate (15 & over) size                            124
# Literacy rate (15-24)                                     124
# Literacy rate (15-24) standard error                      124
# Literacy rate (15-24) size                                124
# Literacy rate (15-19)                                     124
# Literacy rate (15-19) standard error                      124
# Literacy rate (15-19) size                                124
# Literacy rate (25-49)                                     124
# Literacy rate (25-49) standard error                      124
# Literacy rate (25-49) size                                124
# Access to improved water (% of population)                  1
# Improved Water (% of pop) standard error                    1
# Improved Water (% of pop) sample size                       1
# Access to improved sanitation (% of population)             1
# Improved Sanitation (% of pop) standard error               1
# Improved Sanitation (% of pop) sample size                  1
# Electricity in household (% of population)                 22
# Electricity (% of pop) standard error                      22
# Electricity (% of pop) sample size                         22
# Radio in household (% of population)                       10
# Radio (% of pop) standard error                            10
# Radio (% of pop) sample size                               10
# Television in household (% of population)                  10
# Television (% of pop) standard error                       10
# Television (% of pop) sample size                          10
# Radio and/or Television in household (% of population)     10
# Radio and/or TV (% of pop) standard error                  10
# Radio and/or TV (% of pop) sample size                     10
# Access to improved water (% of households)                  1
# Improved Water (% of hh) standard error                     1
# Improved Water (% of hh) sample size                        1
# Access to improved sanitation (% of households)             1
# Improved Sanitation (% of hh) standard error                1
# Improved Sanitation (% of hh) sample size                   1
# Electricity in household (% of households)                 22
# Electricity (% of hh) standard error                       22
# Electricity (% of hh) sample size                          22
# Radio in household (% of households)                       10
# Radio (% of hh) standard error                             10
# Radio (% of hh) sample size                                10
# Television in household (% of households)                  10
# Television (% of hh) standard error                        10
# Television (% of hh) sample size                           10
# Radio and/or television in household (% of households)     10
# Radio and/or TV (% of hh) standard error                   10
# Radio and/or TV (% of hh) sample size                      10
# dtype: int64

# %% [markdown]
# i feel the columns with about 10 and below missing values can be replaced with the mean but a better method has to be used for the ones as high as 124

# %%
df.describe()
# Out:
#        ISO numeric code  CCAPS subnational region ID         Year  \
# count        471.000000                   471.000000   471.000000
# mean         497.152866                497161.866242  2008.131635
# std          240.493840                240494.277329     2.053455
# min          108.000000                108002.000000  2003.000000
# 25%          279.000000                279003.500000  2006.000000
# 50%          478.000000                478012.000000  2008.000000
# 75%          706.000000                706014.500000  2010.000000
# max          894.000000                894009.000000  2011.000000
#
#        Net primary attendance rate (%)  Primary NAR standard error  \
# count                       470.000000                  470.000000
# mean                         69.950883                    2.544909
# std                          21.433693                    1.352500
# min                           0.883070                    0.502372
# 25%                          58.579866                    1.517093
# 50%                          77.421120                    2.203969
# 75%                          86.091373                    3.332346
# max                          96.317795                    7.193609
#
#        Primary NAR sample size  Gross primary attendance rate (%)  \
# count               470.000000                         470.000000
# mean                971.844681                         102.799593
# std                 936.529013                          31.096263
# min                  71.000000                           2.753213
# 25%                 555.500000                          91.004612
# 50%                 825.000000                         103.641014
# 75%                1176.250000                         123.223074
# max               14398.000000                         187.504471
#
#        Primary GAR standard error  Primary GAR sample size  \
# count                  470.000000               470.000000
# mean                     4.359389              1035.585106
# std                      1.942204               940.250504
# min                      1.029757                71.000000
# 25%                      3.078526               638.000000
# 50%                      3.877652               875.000000
# 75%                      5.425325              1227.750000
# max                     15.330481             14405.000000
#
#        Net secondary attendance rate (%)  Secondary NAR standard error  \
# count                         470.000000                    470.000000
# mean                           29.586993                      2.813817
# std                            20.701757                      1.415996
# min                             0.000000                      0.000000
# 25%                            13.646321                      1.873236
# 50%                            24.263889                      2.569867
# 75%                            40.819109                      3.493520
# max                            84.347824                     10.434128
#
#        Secondar NAR sample size  Gross secondary attendance rate (%)  \
# count                470.000000                           470.000000
# mean                 671.478723                            46.098336
# std                  457.832059                            28.878346
# min                   42.000000                             0.000000
# 25%                  382.250000                            23.477402
# 50%                  587.500000                            40.171329
# 75%                  792.000000                            64.574641
# max                 4842.000000                           145.247025
#
#        Secondary GAR standard error  Secondary GAR sample size  \
# count                    470.000000                 470.000000
# mean                       4.296504                 711.746809
# std                        2.183945                 481.824506
# min                        0.000000                  45.000000
# 25%                        2.792217                 421.750000
# 50%                        3.808723                 611.500000
# 75%                        5.209053                 832.000000
# max                       14.922399                4853.000000
#
#        Literacy rate (15 & over)  Literacy rate (15 & over) standard error  \
# count                 347.000000                                347.000000
# mean                   61.434973                                  2.627702
# std                    25.397349                                  1.517131
# min                     9.497565                                  0.153905
# 25%                    43.382933                                  1.586654
# 50%                    66.046158                                  2.336796
# 75%                    81.646332                                  3.522886
# max                    98.898605                                  8.128676
#
#        Literacy rate (15 & over) size  Literacy rate (15-24)  \
# count                      347.000000             347.000000
# mean                      1806.498559              67.072803
# std                       1507.064101              24.195768
# min                        350.000000              10.415296
# 25%                       1105.500000              51.189569
# 50%                       1393.000000              71.427422
# 75%                       1970.000000              87.865166
# max                      13994.000000              99.634010
#
#        Literacy rate (15-24) standard error  Literacy rate (15-24) size  \
# count                            347.000000                  347.000000
# mean                               2.989891                  852.760807
# std                                1.717665                  732.352751
# min                                0.107816                  104.000000
# 25%                                1.775956                  434.500000
# 50%                                2.742748                  650.000000
# 75%                                4.024814                 1030.500000
# max                                9.101959                 6015.000000
#
#        Literacy rate (15-19)  Literacy rate (15-19) standard error  \
# count             347.000000                            347.000000
# mean               71.134001                              3.523134
# std                22.232864                              2.063453
# min                12.650104                              0.193470
# 25%                57.099506                              2.024794
# 50%                75.423141                              3.241239
# 75%                90.226864                              4.448523
# max                99.664429                             12.317142
#
#        Literacy rate (15-19) size  Literacy rate (25-49)  \
# count                  347.000000             347.000000
# mean                   374.775216              57.286808
# std                    301.652187              27.039922
# min                     52.000000               4.976739
# 25%                    217.500000              36.393225
# 50%                    293.000000              61.075508
# 75%                    425.500000              77.263718
# max                   3119.000000              98.958878
#
#        Literacy rate (25-49) standard error  Literacy rate (25-49) size  \
# count                            347.000000                  347.000000
# mean                               2.787651                 1023.190202
# std                                1.542747                  790.544181
# min                                0.176317                  226.000000
# 25%                                1.697982                  634.500000
# 50%                                2.410761                  826.000000
# 75%                                3.693015                 1160.000000
# max                                9.235173                 8181.000000
#
#        Access to improved water (% of population)  \
# count                                  470.000000
# mean                                    60.442817
# std                                     24.733905
# min                                      0.000000
# 25%                                     41.069965
# 50%                                     64.240891
# 75%                                     79.161705
# max                                    100.000000
#
#        Improved Water (% of pop) standard error  \
# count                                470.000000
# mean                                   4.163505
# std                                    2.741863
# min                                    0.000000
# 25%                                    1.854867
# 50%                                    3.808712
# 75%                                    5.802433
# max                                   14.950254
#
#        Improved Water (% of pop) sample size  \
# count                             470.000000
# mean                             5306.778723
# std                              3981.937583
# min                               427.000000
# 25%                              3432.750000
# 50%                              4582.000000
# 75%                              6119.750000
# max                             54841.000000
#
#        Access to improved sanitation (% of population)  \
# count                                       470.000000
# mean                                         40.165780
# std                                          29.219446
# min                                           0.000000
# 25%                                          15.250207
# 50%                                          35.081390
# 75%                                          59.746507
# max                                         100.000000
#
#        Improved Sanitation (% of pop) standard error  \
# count                                     470.000000
# mean                                        2.955834
# std                                         1.995369
# min                                         0.000000
# 25%                                         1.547232
# 50%                                         2.621436
# 75%                                         4.171311
# max                                         9.014301
#
#        Improved Sanitation (% of pop) sample size  \
# count                                  470.000000
# mean                                  5302.602128
# std                                   3981.623067
# min                                    427.000000
# 25%                                   3432.750000
# 50%                                   4553.500000
# 75%                                   6113.250000
# max                                  54831.000000
#
#        Electricity in household (% of population)  \
# count                                  449.000000
# mean                                    28.916043
# std                                     30.222012
# min                                      0.000000
# 25%                                      5.400793
# 50%                                     14.685029
# 75%                                     49.463890
# max                                    100.000000
#
#        Electricity (% of pop) standard error  \
# count                             449.000000
# mean                                2.885390
# std                                 2.477114
# min                                 0.000000
# 25%                                 0.949273
# 50%                                 1.995803
# 75%                                 4.241601
# max                                13.054160
#
#        Electricity (% of pop) sample size  \
# count                          449.000000
# mean                          5296.064588
# std                           4027.472117
# min                            427.000000
# 25%                           3466.000000
# 50%                           4535.000000
# 75%                           6034.000000
# max                          54796.000000
#
#        Radio in household (% of population)  Radio (% of pop) standard error  \
# count                            461.000000                       461.000000
# mean                              62.570418                         2.661125
# std                               16.507053                         1.198700
# min                                2.983278                         0.635185
# 25%                               52.243156                         1.919021
# 50%                               64.244965                         2.390635
# 75%                               75.168182                         3.114528
# max                               94.830490                         7.898751
#
#        Radio (% of pop) sample size  \
# count                    461.000000
# mean                    5354.130152
# std                     4003.160271
# min                      427.000000
# 25%                     3501.000000
# 50%                     4584.000000
# 75%                     6174.000000
# max                    54856.000000
#
#        Television in household (% of population)  \
# count                                 461.000000
# mean                                   25.859050
# std                                    27.005865
# min                                     0.000000
# 25%                                     5.681203
# 50%                                    15.490319
# 75%                                    39.504730
# max                                    99.848709
#
#        Television (% of pop) standard error  \
# count                            461.000000
# mean                               2.462269
# std                                1.836991
# min                                0.000000
# 25%                                1.062360
# 50%                                2.040336
# 75%                                3.445614
# max                               12.657615
#
#        Television (% of pop) sample size  \
# count                         461.000000
# mean                         5353.002169
# std                          4002.051709
# min                           427.000000
# 25%                          3504.000000
# 50%                          4585.000000
# 75%                          6174.000000
# max                         54832.000000
#
#        Radio and/or Television in household (% of population)  \
# count                                         461.000000
# mean                                           66.361430
# std                                            18.480074
# min                                             2.983278
# 25%                                            54.014050
# 50%                                            67.677483
# 75%                                            79.805305
# max                                            99.906143
#
#        Radio and/or TV (% of pop) standard error  \
# count                                 461.000000
# mean                                    2.578027
# std                                     1.351008
# min                                     0.063380
# 25%                                     1.757052
# 50%                                     2.333215
# 75%                                     3.148089
# max                                    11.796641
#
#        Radio and/or TV (% of pop) sample size  \
# count                              461.000000
# mean                              5358.386117
# std                               4005.605396
# min                                427.000000
# 25%                               3514.000000
# 50%                               4599.000000
# 75%                               6174.000000
# max                              54864.000000
#
#        Access to improved water (% of households)  \
# count                                  470.000000
# mean                                    60.583051
# std                                     24.759551
# min                                      0.000000
# 25%                                     41.717515
# 50%                                     64.540665
# 75%                                     79.457344
# max                                    100.000000
#
#        Improved Water (% of hh) standard error  \
# count                               470.000000
# mean                                  4.013583
# std                                   2.711233
# min                                   0.000000
# 25%                                   1.598617
# 50%                                   3.774236
# 75%                                   5.723002
# max                                  14.109353
#
#        Improved Water (% of hh) sample size  \
# count                            470.000000
# mean                            1072.791489
# std                              852.481037
# min                              102.000000
# 25%                              737.000000
# 50%                              902.000000
# 75%                             1182.250000
# max                            12100.000000
#
#        Access to improved sanitation (% of households)  \
# count                                       470.000000
# mean                                         39.920602
# std                                          29.018789
# min                                           0.000000
# 25%                                          16.246583
# 50%                                          35.034931
# 75%                                          57.424318
# max                                         100.000000
#
#        Improved Sanitation (% of hh) standard error  \
# count                                    470.000000
# mean                                       2.838389
# std                                        1.978184
# min                                        0.000000
# 25%                                        1.302251
# 50%                                        2.540909
# 75%                                        4.030688
# max                                        8.712952
#
#        Improved Sanitation (% of hh) sample size  \
# count                                 470.000000
# mean                                 1071.255319
# std                                   850.529354
# min                                   102.000000
# 25%                                   736.250000
# 50%                                   900.000000
# 75%                                  1180.250000
# max                                 12099.000000
#
#        Electricity in household (% of households)  \
# count                                  449.000000
# mean                                    28.546700
# std                                     29.922263
# min                                      0.000000
# 25%                                      4.882430
# 50%                                     15.281693
# 75%                                     49.679600
# max                                    100.000000
#
#        Electricity (% of hh) standard error  \
# count                            449.000000
# mean                               2.764106
# std                                2.420368
# min                                0.000000
# 25%                                0.834932
# 50%                                1.846845
# 75%                                4.271471
# max                               11.943622
#
#        Electricity (% of hh) sample size  \
# count                         449.000000
# mean                         1027.467706
# std                           823.641573
# min                           102.000000
# 25%                           731.000000
# 50%                           885.000000
# 75%                          1133.000000
# max                         12090.000000
#
#        Radio in household (% of households)  Radio (% of hh) standard error  \
# count                            461.000000                      461.000000
# mean                              59.583969                        2.482746
# std                               16.685966                        1.089360
# min                                3.043058                        0.671314
# 25%                               47.636208                        1.821142
# 50%                               61.827236                        2.266243
# 75%                               71.969780                        2.880734
# max                               94.478531                        8.593001
#
#        Radio (% of hh) sample size  Television in household (% of households)  \
# count                   461.000000                                 461.000000
# mean                   1039.026030                                  24.049675
# std                     819.500441                                  26.032103
# min                     102.000000                                   0.000000
# 25%                     735.000000                                   4.730056
# 50%                     897.000000                                  13.933089
# 75%                    1145.000000                                  36.818672
# max                   12103.000000                                  99.795082
#
#        Television (% of hh) standard error  Television (% of hh) sample size  \
# count                           461.000000                        461.000000
# mean                              2.227461                       1038.809111
# std                               1.728585                        819.240206
# min                               0.000000                        102.000000
# 25%                               0.876031                        735.000000
# 50%                               1.707531                        897.000000
# 75%                               3.190341                       1143.000000
# max                              11.930634                      12097.000000
#
#        Radio and/or television in household (% of households)  \
# count                                         461.000000
# mean                                           63.282087
# std                                            18.901273
# min                                             3.043058
# 25%                                            48.983479
# 50%                                            65.037926
# 75%                                            76.907753
# max                                            99.795082
#
#        Radio and/or TV (% of hh) standard error  \
# count                                461.000000
# mean                                   2.438457
# std                                    1.237110
# min                                    0.200288
# 25%                                    1.705319
# 50%                                    2.272248
# 75%                                    2.930026
# max                                   11.807983
#
#        Radio and/or TV (% of hh) sample size
# count                             461.000000
# mean                             1039.780911
# std                               819.836493
# min                               102.000000
# 25%                               735.000000
# 50%                               897.000000
# 75%                              1146.000000
# max                             12105.000000

# %%
df['Year'].unique()
# Out:
# array([2011, 2006, 2010, 2005, 2008, 2009, 2007, 2003])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df['Net primary attendance rate (%)'], kde=True)
plt.title('Distribution of Net primary attendance rate (%)')
plt.show()

# %%
sns.histplot(df['Net secondary attendance rate (%)'], kde=True)
plt.title('Distribution of Net secondary attendance rate (%)')
plt.show()

# %% [markdown]
# Check for the distribution for other columns by copying the column name from the table and replacing the one in the code with it.

# %%
sns.scatterplot(x='Access to improved sanitation (% of households)', y='Gross secondary attendance rate (%)', data=df)
plt.title('Relationship between Gross secondary attendance rate (%) and Access to improved sanitation (% of households)')
plt.show()

# %% [markdown]
# you can change X and Y in the code for any two variables you want to check for

# %%
correlation_matrix = df.corr()

# Create a heatmap
plt.figure(figsize=(12, 10))  # Adjust the figure size as needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Nah! too much columns for it to make sense

# %% [markdown]
# ## correcting missing values

# %%
from sklearn.impute import SimpleImputer, KNNImputer

# Columns with missing values up to 10
columns_to_impute_mean = df.columns[df.isnull().sum() <= 10]

# Impute missing values with the mean for numerical columns, and most frequent for categorical columns
for col in columns_to_impute_mean:
    if df[col].dtype == 'object':
        imputer = SimpleImputer(strategy='most_frequent')
    else:
        imputer = SimpleImputer(strategy='mean')
    df[col] = imputer.fit_transform(df[[col]])

# Columns with missing values from 11 to 23
columns_to_impute_predictive = df.columns[(df.isnull().sum() > 10) & (df.isnull().sum() <= 23)]

# Impute missing values using KNN imputation for these columns
if not columns_to_impute_predictive.empty:
    knn_imputer = KNNImputer(n_neighbors=5)  # You can adjust the number of neighbors
    df[columns_to_impute_predictive] = knn_imputer.fit_transform(df[columns_to_impute_predictive])

# Remove columns with missing values above 23
columns_to_remove = df.columns[df.isnull().sum() > 23]
df.drop(columns=columns_to_remove, inplace=True)

# %% [markdown]
# **K-Nearest Neighbors (KNN)** imputation is a technique used to fill missing values in a dataset based on the values of its nearest neighbors. Here's how KNN imputation works:
#
# **1. Select a Distance Metric:** The first step is to choose a distance metric to measure the similarity between data points. Common distance metrics include Euclidean distance, Manhattan distance, or Minkowski distance. The choice of distance metric depends on the nature of your data and the problem you are trying to solve.
#
# **2. Identify Neighbors:** For each data point with missing values, KNN identifies its k-nearest neighbors from the dataset based on the chosen distance metric. These neighbors are the data points that are most similar to the one with missing values.
#
# **3. Calculate Weighted Average:** KNN computes a weighted average of the observed values of the feature in question from the k-nearest neighbors. The weights are typically based on the inverse of the distances; closer neighbors have a higher influence on the imputed value than more distant neighbors.
#
# **4. Fill Missing Values:** The calculated weighted average is used to fill in the missing value for the feature in question in the data point. This process is repeated for each missing value in the dataset.

# %%
pd.set_option('display.max_rows', None)
null_values = df.isnull().sum()

print("Columns with Null Values:")
print(null_values)
# Out:
# Columns with Null Values:
# Country name                                              0
# ISO code                                                  0
# ISO numeric code                                          0
# Subnational region name                                   0
# CCAPS subnational region ID                               0
# Year                                                      0
# Data Source                                               0
# Website                                                   0
# Net primary attendance rate (%)                           0
# Primary NAR standard error                                0
# Primary NAR sample size                                   0
# Gross primary attendance rate (%)                         0
# Primary GAR standard error                                0
# Primary GAR sample size                                   0
# Net secondary attendance rate (%)                         0
# Secondary NAR standard error                              0
# Secondar NAR sample size                                  0
# Gross secondary attendance rate (%)                       0
# Secondary GAR standard error                              0
# Secondary GAR sample size                                 0
# Access to improved water (% of population)                0
# Improved Water (% of pop) standard error                  0
# Improved Water (% of pop) sample size                     0
# Access to improved sanitation (% of population)           0
# Improved Sanitation (% of pop) standard error             0
# Improved Sanitation (% of pop) sample size                0
# Electricity in household (% of population)                0
# Electricity (% of pop) standard error                     0
# Electricity (% of pop) sample size                        0
# Radio in household (% of population)                      0
# Radio (% of pop) standard error                           0
# Radio (% of pop) sample size                              0
# Television in household (% of population)                 0
# Television (% of pop) standard error                      0
# Television (% of pop) sample size                         0
# Radio and/or Television in household (% of population)    0
# Radio and/or TV (% of pop) standard error                 0
# Radio and/or TV (% of pop) sample size                    0
# Access to improved water (% of households)                0
# Improved Water (% of hh) standard error                   0
# Improved Water (% of hh) sample size                      0
# Access to improved sanitation (% of households)           0
# Improved Sanitation (% of hh) standard error              0
# Improved Sanitation (% of hh) sample size                 0
# Electricity in household (% of households)                0
# Electricity (% of hh) standard error                      0
# Electricity (% of hh) sample size                         0
# Radio in household (% of households)                      0
# Radio (% of hh) standard error                            0
# Radio (% of hh) sample size                               0
# Television in household (% of households)                 0
# Television (% of hh) standard error                       0
# Television (% of hh) sample size                          0
# Radio and/or television in household (% of households)    0
# Radio and/or TV (% of hh) standard error                  0
# Radio and/or TV (% of hh) sample size                     0
# dtype: int64

# %%
# Check for duplicate rows
duplicate_rows = df[df.duplicated()]

# Display duplicate rows, if any
if not duplicate_rows.empty:
    print("Duplicate Rows:")
    print(duplicate_rows)
else:
    print("No Duplicate Rows found.")
# Out:
# No Duplicate Rows found.

# %%
from google.colab import files

# Assuming df is your cleaned DataFrame
df.to_csv('cleaned_dataset.csv', index=False)

# Download the CSV file
files.download('cleaned_dataset.csv')

# %% [markdown]
# ## This will download the cleaned data into your laptop

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assume your data frame is df_melted
sns.boxplot(x= df[features], y= df['Net secondary attendance rate (%)'], data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-a8b67f5cd00f> in <cell line: 5>()
#       3
#       4 # Assume your data frame is df_melted
# ----> 5 sns.boxplot(x= df[features], y= df['Net secondary attendance rate (%)'], data=df)
#
# NameError: name 'features' is not defined

# %% [markdown]
# # Futher exploration and plot

# %%
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
sns.regplot(x='Access to improved sanitation (% of population)', y='Net secondary attendance rate (%)', data = df)
# Out:
# <Axes: xlabel='Access to improved sanitation (% of population)', ylabel='Net secondary attendance rate (%)'>

# %%
features = ['Access to improved water (% of population)', 'Access to improved sanitation (% of population)','Electricity in household (% of population)','Radio and/or television in household (% of households)' ]

# %%
x= df[features]
y= df['Net secondary attendance rate (%)']

# %%
lm = LinearRegression()
lm.fit(x,y)
lm.score(x,y)
# Out:
# 0.6173912924698326

# %%
sns.boxplot(x=df['Access to improved water (% of population)'], palette=["m", "g"], data=df)
# Out:
# <Axes: xlabel='Access to improved water (% of population)'>

# %%
# List of columns related to educational infrastructure
columns_education = [
    'Net primary attendance rate (%)',
    'Gross primary attendance rate (%)',
    'Access to improved water (% of population)',
    'Access to improved sanitation (% of population)',
    'Electricity in household (% of population)',
    'Radio in household (% of population)',
    'Television in household (% of population)'
]

# Generate insights
# Attendance Rates
print("Attendance Rates:")
for col in ['Net primary attendance rate (%)', 'Gross primary attendance rate (%)']:
    print(f"Average {col}: {df[col].mean():.2f}")

# # Literacy Rates
# print("\nLiteracy Rates:")
# for col in ['Literacy rate (15 & over)', 'Literacy rate (15-24)']:
#     print(f"Average {col}: {df[col].mean():.2f}")

# Sample Sizes
print("\nSample Sizes:")
for col in ['Primary NAR sample size', 'Secondar NAR sample size']:
    print(f"Average {col}: {df[col].mean():.2f}")

# Standard Errors
print("\nStandard Errors:")
for col in ['Primary NAR standard error', 'Secondary NAR standard error']:
    print(f"Average {col}: {df[col].mean():.2f}")

# Impact on Education
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))
axes = axes.flatten()

df.plot.scatter(x='Access to improved water (% of population)', y='Gross primary attendance rate (%)', ax=axes[0])
axes[0].set_title("Access to Water vs. Gross primary attendance rate (%)")

df.plot.scatter(x='Access to improved sanitation (% of population)', y='Gross primary attendance rate (%)', ax=axes[1])
axes[1].set_title("Access to Sanitation vs. Gross primary attendance rate (%)")

df.plot.scatter(x='Electricity in household (% of population)', y='Gross primary attendance rate (%)', ax=axes[2])
axes[2].set_title("Electricity vs. Gross primary attendance rate (%)")

df.plot.scatter(x='Radio in household (% of population)', y='Gross primary attendance rate (%)', ax=axes[3])
axes[3].set_title("Radio in Household vs. Gross primary attendance rate (%)")

plt.tight_layout()
plt.show()
# Out:
# Attendance Rates:
# Average Net primary attendance rate (%): 69.95
# Average Gross primary attendance rate (%): 102.80
#
# Sample Sizes:
# Average Primary NAR sample size: 971.84
# Average Secondar NAR sample size: 671.48
#
# Standard Errors:
# Average Primary NAR standard error: 2.54
# Average Secondary NAR standard error: 2.81

# %%
attendance_columns = [
    'Net primary attendance rate (%)',
    'Gross primary attendance rate (%)',
    'Net secondary attendance rate (%)',
    'Gross secondary attendance rate (%)'
]

attendance_df = df[attendance_columns]

# Calculate summary statistics
summary_stats = attendance_df.describe()

# Identify regions or years with high attendance rates
high_attendance_regions = df.nlargest(10, 'Net primary attendance rate (%)')  # Change column name as needed
low_attendance_regions = df.nsmallest(10, 'Net primary attendance rate (%)')  # Change column name as needed

import matplotlib.pyplot as plt

plt.hist(df['Net primary attendance rate (%)'], bins=20, edgecolor='k')
plt.xlabel('Net Primary Attendance Rate (%)')
plt.ylabel('Count')
plt.title('Primary Net Attendance Rate Distribution')
plt.show()

# %%
high_attendance_regions
# Out:
#               Country name ISO code  ISO numeric code Subnational region name  \
# 428             Mauritania      MRT             478.0                  Trarza
# 460                   Togo      TGO             768.0                Plateaux
# 306  Sao Tome and Principe      STP             678.0                Principe
# 419             Mauritania      MRT             478.0      Dakhlet Nouadhibou
# 424             Mauritania      MRT             478.0                 Inchiri
# 458                   Togo      TGO             768.0                    Kara
# 51                Cameroon      CMR             120.0                   Ouest
# 427             Mauritania      MRT             478.0           Tiris Zemmour
# 47                Cameroon      CMR             120.0                Littoral
# 416             Mauritania      MRT             478.0                   Adrar
#
#      CCAPS subnational region ID    Year Data Source  \
# 428                     478013.0  2007.0        MICS
# 460                     768005.0  2006.0        MICS
# 306                     678001.0  2009.0         DHS
# 419                     478004.0  2007.0        MICS
# 424                     478009.0  2007.0        MICS
# 458                     768003.0  2006.0        MICS
# 51                      120009.0  2011.0         DHS
# 427                     478012.0  2007.0        MICS
# 47                      120005.0  2011.0         DHS
# 416                     478001.0  2007.0        MICS
#
#                         Website  Net primary attendance rate (%)  \
# 428  www.unicef.org/statistics/                        96.317795
# 460  www.unicef.org/statistics/                        95.512596
# 306          www.measuredhs.com                        95.413872
# 419  www.unicef.org/statistics/                        95.342377
# 424  www.unicef.org/statistics/                        95.267334
# 458  www.unicef.org/statistics/                        95.006828
# 51           www.measuredhs.com                        94.942215
# 427  www.unicef.org/statistics/                        94.601151
# 47           www.measuredhs.com                        94.303009
# 416  www.unicef.org/statistics/                        94.154655
#
#      Primary NAR standard error  Primary NAR sample size  \
# 428                    1.042992                    396.0
# 460                    0.885136                    753.0
# 306                    2.045817                    323.0
# 419                    0.927063                    503.0
# 424                    2.590615                    101.0
# 458                    0.923822                    670.0
# 51                     0.663587                   1243.0
# 427                    1.406710                    288.0
# 47                     0.986372                    640.0
# 416                    1.390341                    384.0
#
#      Gross primary attendance rate (%)  Primary GAR standard error  \
# 428                         168.945587                    5.691159
# 460                         143.683212                    3.522377
# 306                         150.556335                    4.381925
# 419                         146.273727                    3.912453
# 424                         164.252121                   14.293688
# 458                         154.227844                    3.948357
# 51                          138.167648                    1.888700
# 427                         149.863510                    5.674300
# 47                          133.251831                    3.358329
# 416                         157.474228                    5.192665
#
#      Primary GAR sample size  Net secondary attendance rate (%)  \
# 428                    787.0                          23.863319
# 460                    983.0                          38.066490
# 306                    323.0                          27.142071
# 419                    708.0                          26.450691
# 424                    183.0                          32.425499
# 458                   1022.0                          30.598280
# 51                    1243.0                          64.918419
# 427                    386.0                          30.106670
# 47                     641.0                          60.340488
# 416                    528.0                          23.291843
#
#      Secondary NAR standard error  Secondar NAR sample size  \
# 428                      2.066721                     503.0
# 460                      2.092045                     749.0
# 306                      8.510447                     249.0
# 419                      2.208235                     565.0
# 424                      5.718036                     136.0
# 458                      1.927442                     705.0
# 51                       2.394849                    1058.0
# 427                      2.905679                     337.0
# 47                       2.289795                     647.0
# 416                      2.467579                     434.0
#
#      Gross secondary attendance rate (%)  Secondary GAR standard error  \
# 428                            38.202087                      2.898031
# 460                            46.729321                      2.450806
# 306                            44.428711                     14.922399
# 419                            38.267662                      2.787140
# 424                            44.385853                      6.794299
# 458                            44.289059                      2.445545
# 51                             89.560280                      4.027975
# 427                            45.874611                      4.016211
# 47                             89.710388                      4.187463
# 416                            39.937046                      3.673710
#
#      Secondary GAR sample size  Access to improved water (% of population)  \
# 428                      707.0                                   86.049355
# 460                      876.0                                   41.545502
# 306                      249.0                                   60.365452
# 419                      653.0                                   89.664665
# 424                      166.0                                   77.261559
# 458                      855.0                                   62.103916
# 51                      1062.0                                   66.601547
# 427                      377.0                                   16.311771
# 47                       648.0                                   82.954575
# 416                      471.0                                   50.027363
#
#      Improved Water (% of pop) standard error  \
# 428                                  1.164071
# 460                                  1.469487
# 306                                 14.950254
# 419                                  1.120482
# 424                                  2.931515
# 458                                  1.817374
# 51                                   3.951638
# 427                                  1.501048
# 47                                   3.642539
# 416                                  2.107674
#
#      Improved Water (% of pop) sample size  \
# 428                                 4283.0
# 460                                 5214.0
# 306                                 1846.0
# 419                                 4312.0
# 424                                 1132.0
# 458                                 5073.0
# 51                                  6361.0
# 427                                 2445.0
# 47                                  4085.0
# 416                                 2815.0
#
#      Access to improved sanitation (% of population)  \
# 428                                        60.357170
# 460                                        17.177549
# 306                                        37.869308
# 419                                        79.038170
# 424                                        43.956600
# 458                                         9.157192
# 51                                         51.579254
# 427                                        87.679604
# 47                                         57.607239
# 416                                        41.247513
#
#      Improved Sanitation (% of pop) standard error  \
# 428                                       1.763697
# 460                                       1.222514
# 306                                       7.292931
# 419                                       1.486028
# 424                                       4.197429
# 458                                       1.103522
# 51                                        4.704474
# 427                                       1.418069
# 47                                        4.367334
# 416                                       2.150578
#
#      Improved Sanitation (% of pop) sample size  \
# 428                                      4283.0
# 460                                      5214.0
# 306                                      1846.0
# 419                                      4312.0
# 424                                      1132.0
# 458                                      5073.0
# 51                                       6361.0
# 427                                      2445.0
# 47                                       4077.0
# 416                                      2815.0
#
#      Electricity in household (% of population)  \
# 428                                   22.436237
# 460                                   18.451736
# 306                                   60.230423
# 419                                   94.470634
# 424                                   61.898170
# 458                                   21.002357
# 51                                    59.006237
# 427                                   87.686714
# 47                                    74.363708
# 416                                   47.303394
#
#      Electricity (% of pop) standard error  \
# 428                               1.361145
# 460                               1.210549
# 306                               9.053837
# 419                               0.592362
# 424                               3.396037
# 458                               1.410208
# 51                                6.702223
# 427                               1.603021
# 47                                5.417156
# 416                               1.912877
#
#      Electricity (% of pop) sample size  Radio in household (% of population)  \
# 428                              4276.0                             59.624146
# 460                              5214.0                             73.428040
# 306                              1846.0                             65.126350
# 419                              4323.0                             60.653431
# 424                              1125.0                             63.359642
# 458                              5069.0                             76.365936
# 51                               6361.0                             66.773132
# 427                              2445.0                             56.076920
# 47                               4085.0                             61.021267
# 416                              2802.0                             67.632767
#
#      Radio (% of pop) standard error  Radio (% of pop) sample size  \
# 428                         1.955781                        4286.0
# 460                         1.460545                        5214.0
# 306                         7.467397                        1846.0
# 419                         2.099773                        4320.0
# 424                         4.024259                        1132.0
# 458                         1.570649                        5073.0
# 51                          2.063956                        6361.0
# 427                         2.593669                        2445.0
# 47                          3.242780                        4085.0
# 416                         2.224997                        2812.0
#
#      Television in household (% of population)  \
# 428                                  22.220598
# 460                                  15.490319
# 306                                  58.279842
# 419                                  86.399338
# 424                                  51.526623
# 458                                  11.381464
# 51                                   49.966381
# 427                                  79.716629
# 47                                   58.609558
# 416                                  39.306087
#
#      Television (% of pop) standard error  Television (% of pop) sample size  \
# 428                              1.528691                             4277.0
# 460                              1.389799                             5214.0
# 306                             11.391050                             1846.0
# 419                              1.088764                             4318.0
# 424                              3.795045                             1132.0
# 458                              1.182973                             5073.0
# 51                               4.246894                             6361.0
# 427                              1.894766                             2434.0
# 47                               3.836766                             4085.0
# 416                              2.095374                             2808.0
#
#      Radio and/or Television in household (% of population)  \
# 428                                          67.206955
# 460                                          73.619041
# 306                                          69.868866
# 419                                          93.766632
# 424                                          76.605217
# 458                                          76.449188
# 51                                           75.139992
# 427                                          86.582710
# 47                                           77.321899
# 416                                          75.953995
#
#      Radio and/or TV (% of pop) standard error  \
# 428                                   1.822530
# 460                                   1.458755
# 306                                   7.186094
# 419                                   0.845486
# 424                                   3.400763
# 458                                   1.569511
# 51                                    1.897144
# 427                                   1.590542
# 47                                    2.753835
# 416                                   1.921565
#
#      Radio and/or TV (% of pop) sample size  \
# 428                                  4286.0
# 460                                  5214.0
# 306                                  1846.0
# 419                                  4323.0
# 424                                  1132.0
# 458                                  5073.0
# 51                                   6361.0
# 427                                  2445.0
# 47                                   4085.0
# 416                                  2815.0
#
#      Access to improved water (% of households)  \
# 428                                   85.975945
# 460                                   41.848873
# 306                                   59.886021
# 419                                   87.859390
# 424                                   76.938728
# 458                                   64.552170
# 51                                    67.814545
# 427                                   17.404860
# 47                                    83.136124
# 416                                   49.958359
#
#      Improved Water (% of hh) standard error  \
# 428                                 0.919767
# 460                                 1.110713
# 306                                14.109353
# 419                                 0.975307
# 424                                 2.472443
# 458                                 1.396317
# 51                                  3.373726
# 427                                 1.198209
# 47                                  3.371854
# 416                                 1.714211
#
#      Improved Water (% of hh) sample size  \
# 428                                 804.0
# 460                                1191.0
# 306                                 525.0
# 419                                 829.0
# 424                                 265.0
# 458                                 967.0
# 51                                 1271.0
# 427                                 473.0
# 47                                  927.0
# 416                                 534.0
#
#      Access to improved sanitation (% of households)  \
# 428                                        58.016277
# 460                                        18.240440
# 306                                        32.781990
# 419                                        76.250549
# 424                                        45.744198
# 458                                         9.860663
# 51                                         51.839153
# 427                                        85.230301
# 47                                         58.717804
# 416                                        39.659775
#
#      Improved Sanitation (% of hh) standard error  \
# 428                                      1.527213
# 460                                      1.027208
# 306                                      5.751267
# 419                                      1.226197
# 424                                      3.500038
# 458                                      0.984770
# 51                                       3.351482
# 427                                      1.446455
# 47                                       3.763530
# 416                                      1.796142
#
#      Improved Sanitation (% of hh) sample size  \
# 428                                      804.0
# 460                                     1191.0
# 306                                      525.0
# 419                                      829.0
# 424                                      265.0
# 458                                      967.0
# 51                                      1271.0
# 427                                      473.0
# 47                                       924.0
# 416                                      534.0
#
#      Electricity in household (% of households)  \
# 428                                   20.094200
# 460                                   17.624186
# 306                                   53.061928
# 419                                   91.660248
# 424                                   59.959232
# 458                                   21.931271
# 51                                    59.069221
# 427                                   85.942940
# 47                                    73.140297
# 416                                   43.377277
#
#      Electricity (% of hh) standard error  Electricity (% of hh) sample size  \
# 428                              0.957724                              804.0
# 460                              0.914040                             1191.0
# 306                             10.221774                              525.0
# 419                              0.725402                              830.0
# 424                              2.765975                              264.0
# 458                              1.131090                              966.0
# 51                               4.883049                             1271.0
# 427                              1.511966                              473.0
# 47                               4.797928                              927.0
# 416                              1.559321                              532.0
#
#      Radio in household (% of households)  Radio (% of hh) standard error  \
# 428                             58.841896                        1.718211
# 460                             69.021614                        1.361767
# 306                             58.049595                        8.593001
# 419                             63.763523                        1.682437
# 424                             66.318634                        3.334662
# 458                             71.030655                        1.479635
# 51                              60.297024                        2.280759
# 427                             55.159283                        2.264894
# 47                              56.624722                        2.647258
# 416                             64.238701                        2.055070
#
#      Radio (% of hh) sample size  Television in household (% of households)  \
# 428                        805.0                                  19.096943
# 460                       1191.0                                  12.417558
# 306                        525.0                                  48.000629
# 419                        829.0                                  76.242027
# 424                        265.0                                  46.694599
# 458                        967.0                                  10.234467
# 51                        1271.0                                  44.234917
# 427                        473.0                                  74.325478
# 47                         927.0                                  51.116707
# 416                        533.0                                  34.618942
#
#      Television (% of hh) standard error  Television (% of hh) sample size  \
# 428                             1.128019                             803.0
# 460                             0.968033                            1191.0
# 306                            11.930634                             525.0
# 419                             1.381070                             829.0
# 424                             3.169171                             265.0
# 458                             0.959848                             967.0
# 51                              3.447142                            1271.0
# 427                             1.897166                             471.0
# 47                              3.399981                             927.0
# 416                             1.726295                             530.0
#
#      Radio and/or television in household (% of households)  \
# 428                                          64.852921
# 460                                          69.271729
# 306                                          62.091255
# 419                                          90.716515
# 424                                          76.438011
# 458                                          71.176231
# 51                                           68.626839
# 427                                          83.964279
# 47                                           71.632332
# 416                                          72.218697
#
#      Radio and/or TV (% of hh) standard error  \
# 428                                  1.646510
# 460                                  1.359961
# 306                                  8.784486
# 419                                  0.973863
# 424                                  2.838834
# 458                                  1.476563
# 51                                   2.291204
# 427                                  1.615349
# 47                                   2.683986
# 416                                  1.833575
#
#      Radio and/or TV (% of hh) sample size
# 428                                  805.0
# 460                                 1191.0
# 306                                  525.0
# 419                                  830.0
# 424                                  265.0
# 458                                  967.0
# 51                                  1271.0
# 427                                  473.0
# 47                                   927.0
# 416                                  534.0

# %%
low_attendance_regions
# Out:
#     Country name ISO code  ISO numeric code Subnational region name  \
# 446      Somalia      SOM             706.0           Jubbada Dhexe
# 445      Somalia      SOM             706.0                 Hiiraan
# 443      Somalia      SOM             706.0               Galguduud
# 442      Somalia      SOM             706.0                     Bay
# 439      Somalia      SOM             706.0                  Bakool
# 451      Somalia      SOM             706.0       Shabeellaha Dhexe
# 447      Somalia      SOM             706.0           Jubbada Hoose
# 448      Somalia      SOM             706.0                   Mudug
# 452      Somalia      SOM             706.0       Shabeellaha Hoose
# 440      Somalia      SOM             706.0                Banaadir
#
#      CCAPS subnational region ID    Year Data Source  \
# 446                     706009.0  2010.0        MICS
# 445                     706008.0  2010.0        MICS
# 443                     706006.0  2010.0        MICS
# 442                     706005.0  2010.0        MICS
# 439                     706002.0  2010.0        MICS
# 451                     706014.0  2010.0        MICS
# 447                     706010.0  2010.0        MICS
# 448                     706011.0  2010.0        MICS
# 452                     706015.0  2010.0        MICS
# 440                     706003.0  2010.0        MICS
#
#                         Website  Net primary attendance rate (%)  \
# 446  www.unicef.org/statistics/                         0.883070
# 445  www.unicef.org/statistics/                         1.255762
# 443  www.unicef.org/statistics/                         1.267357
# 442  www.unicef.org/statistics/                         3.142123
# 439  www.unicef.org/statistics/                         4.533437
# 451  www.unicef.org/statistics/                         5.740453
# 447  www.unicef.org/statistics/                         7.199344
# 448  www.unicef.org/statistics/                        16.656761
# 452  www.unicef.org/statistics/                        16.804415
# 440  www.unicef.org/statistics/                        18.169209
#
#      Primary NAR standard error  Primary NAR sample size  \
# 446                    0.874960                    155.0
# 445                    0.902903                    188.0
# 443                    0.770899                    315.0
# 442                    1.308757                    446.0
# 439                    1.647754                    239.0
# 451                    1.231258                    405.0
# 447                    2.216101                    212.0
# 448                    2.034245                    566.0
# 452                    1.860776                    615.0
# 440                    1.871319                    721.0
#
#      Gross primary attendance rate (%)  Primary GAR standard error  \
# 446                           2.753213                    1.385325
# 445                           6.897810                    2.665995
# 443                           3.163223                    1.067584
# 442                           7.022099                    1.738445
# 439                           6.853268                    2.209235
# 451                           9.902882                    1.907060
# 447                          20.292173                    4.178246
# 448                          33.874954                    3.489793
# 452                          31.654650                    2.804645
# 440                          38.557560                    3.075280
#
#      Primary GAR sample size  Net secondary attendance rate (%)  \
# 446                    169.0                           0.000000
# 445                    264.0                           0.000000
# 443                    329.0                           0.806663
# 442                    473.0                           0.873786
# 439                    259.0                           0.000000
# 451                    432.0                           3.853387
# 447                    233.0                           0.000000
# 448                    653.0                           1.286180
# 452                    643.0                           1.820678
# 440                    762.0                          12.912912
#
#      Secondary NAR standard error  Secondar NAR sample size  \
# 446                      0.000000                      42.0
# 445                      0.000000                      68.0
# 443                      0.801426                     124.0
# 442                      0.857396                     125.0
# 439                      0.000000                      65.0
# 451                      2.424470                     151.0
# 447                      0.000000                      85.0
# 448                      0.633930                     261.0
# 452                      0.898771                     235.0
# 440                      2.164404                     333.0
#
#      Gross secondary attendance rate (%)  Secondary GAR standard error  \
# 446                             0.000000                      0.000000
# 445                             3.971366                      2.768960
# 443                             2.419990                      1.786612
# 442                             2.621357                      1.489389
# 439                             0.000000                      0.000000
# 451                             8.477451                      4.056084
# 447                             0.000000                      0.000000
# 448                             5.557093                      1.760130
# 452                             3.699761                      1.210931
# 440                            24.624624                      3.165269
#
#      Secondary GAR sample size  Access to improved water (% of population)  \
# 446                       45.0                                   18.138351
# 445                      117.0                                    9.428889
# 443                      160.0                                    8.459377
# 442                      153.0                                   21.961952
# 439                       94.0                                   10.114438
# 451                      202.0                                   26.441946
# 447                      115.0                                   12.828058
# 448                      345.0                                   31.168457
# 452                      298.0                                   18.102629
# 440                      433.0                                   65.651680
#
#      Improved Water (% of pop) standard error  \
# 446                                  1.843956
# 445                                  1.771124
# 443                                  1.454323
# 442                                  1.651517
# 439                                  2.107066
# 451                                  1.402389
# 447                                  1.884961
# 448                                  1.608914
# 452                                  1.528001
# 440                                  1.964232
#
#      Improved Water (% of pop) sample size  \
# 446                                  862.0
# 445                                 1148.0
# 443                                 1337.0
# 442                                 2161.0
# 439                                 1058.0
# 451                                 2011.0
# 447                                 1345.0
# 448                                 2982.0
# 452                                 2986.0
# 440                                 3514.0
#
#      Access to improved sanitation (% of population)  \
# 446                                         8.297934
# 445                                        28.491983
# 443                                        13.292652
# 442                                        18.260618
# 439                                        10.477052
# 451                                        19.969631
# 447                                        17.138882
# 448                                        42.922150
# 452                                        32.418308
# 440                                        94.080818
#
#      Improved Sanitation (% of pop) standard error  \
# 446                                       2.102834
# 445                                       2.530448
# 443                                       2.172450
# 442                                       1.568950
# 439                                       2.053634
# 451                                       1.815996
# 447                                       1.941376
# 448                                       1.709480
# 452                                       1.665083
# 440                                       0.766352
#
#      Improved Sanitation (% of pop) sample size  \
# 446                                       862.0
# 445                                      1148.0
# 443                                      1341.0
# 442                                      2161.0
# 439                                      1058.0
# 451                                      2011.0
# 447                                      1345.0
# 448                                      2982.0
# 452                                      2986.0
# 440                                      3514.0
#
#      Electricity in household (% of population)  \
# 446                                    1.789967
# 445                                    3.916058
# 443                                    3.274471
# 442                                    2.705148
# 439                                    6.408711
# 451                                   11.827600
# 447                                    3.252274
# 448                                   12.592419
# 452                                   13.708504
# 440                                   38.312428
#
#      Electricity (% of pop) standard error  \
# 446                               1.058223
# 445                               1.372353
# 443                               1.301164
# 442                               0.986633
# 439                               1.925054
# 451                               1.714638
# 447                               1.091567
# 448                               1.194240
# 452                               1.441496
# 440                               2.165759
#
#      Electricity (% of pop) sample size  Radio in household (% of population)  \
# 446                               862.0                              2.983278
# 445                              1161.0                             13.866801
# 443                              1341.0                             36.750877
# 442                              2126.0                             25.827810
# 439                              1056.0                             10.331353
# 451                              2003.0                             36.631550
# 447                              1345.0                             24.632370
# 448                              2973.0                             38.239212
# 452                              2990.0                             39.084457
# 440                              3508.0                             72.036560
#
#      Radio (% of pop) standard error  Radio (% of pop) sample size  \
# 446                         1.332002                         862.0
# 445                         2.448635                        1154.0
# 443                         3.541478                        1341.0
# 442                         2.058210                        2161.0
# 439                         2.119099                        1056.0
# 451                         2.510919                        2011.0
# 447                         2.968085                        1345.0
# 448                         2.119122                        2963.0
# 452                         2.090793                        2983.0
# 440                         1.936851                        3501.0
#
#      Television in household (% of population)  \
# 446                                   0.000000
# 445                                   0.330184
# 443                                   0.000000
# 442                                   2.586191
# 439                                   0.000000
# 451                                   4.106770
# 447                                   0.361364
# 448                                   3.089127
# 452                                   5.332200
# 440                                  16.723745
#
#      Television (% of pop) standard error  Television (% of pop) sample size  \
# 446                              0.000000                              862.0
# 445                              0.330565                             1161.0
# 443                              0.000000                             1341.0
# 442                              1.056277                             2161.0
# 439                              0.000000                             1058.0
# 451                              1.327141                             2011.0
# 447                              0.361398                             1345.0
# 448                              0.691561                             2971.0
# 452                              1.133577                             2986.0
# 440                              1.773390                             3504.0
#
#      Radio and/or Television in household (% of population)  \
# 446                                           2.983278
# 445                                          14.116861
# 443                                          36.750877
# 442                                          26.588455
# 439                                          10.312165
# 451                                          36.631550
# 447                                          24.632370
# 448                                          38.253136
# 452                                          39.181751
# 440                                          73.562889
#
#      Radio and/or TV (% of pop) standard error  \
# 446                                   1.332002
# 445                                   2.447836
# 443                                   3.541478
# 442                                   2.017491
# 439                                   2.115492
# 451                                   2.510919
# 447                                   2.968085
# 448                                   2.114599
# 452                                   2.082234
# 440                                   1.872914
#
#      Radio and/or TV (% of pop) sample size  \
# 446                                   862.0
# 445                                  1161.0
# 443                                  1341.0
# 442                                  2161.0
# 439                                  1058.0
# 451                                  2011.0
# 447                                  1345.0
# 448                                  2982.0
# 452                                  2990.0
# 440                                  3514.0
#
#      Access to improved water (% of households)  \
# 446                                   18.258350
# 445                                    9.831812
# 443                                    8.847478
# 442                                   20.183361
# 439                                   10.021016
# 451                                   24.874657
# 447                                   14.070089
# 448                                   31.872038
# 452                                   15.444706
# 440                                   62.847221
#
#      Improved Water (% of hh) standard error  \
# 446                                 1.724546
# 445                                 1.525507
# 443                                 0.946376
# 442                                 1.211859
# 439                                 1.856159
# 451                                 0.958986
# 447                                 1.844040
# 448                                 1.312281
# 452                                 1.139443
# 440                                 1.815804
#
#      Improved Water (% of hh) sample size  \
# 446                                 168.0
# 445                                 214.0
# 443                                 215.0
# 442                                 408.0
# 439                                 192.0
# 451                                 336.0
# 447                                 238.0
# 448                                 576.0
# 452                                 551.0
# 440                                 576.0
#
#      Access to improved sanitation (% of households)  \
# 446                                         9.503523
# 445                                        29.192698
# 443                                        14.278650
# 442                                        15.093777
# 439                                        10.021016
# 451                                        19.088264
# 447                                        15.938075
# 448                                        43.365936
# 452                                        28.245258
# 440                                        93.229172
#
#      Improved Sanitation (% of hh) standard error  \
# 446                                      2.288958
# 445                                      2.192813
# 443                                      1.815056
# 442                                      1.006000
# 439                                      1.825131
# 451                                      1.443830
# 447                                      1.707638
# 448                                      1.356317
# 452                                      1.322523
# 440                                      0.726718
#
#      Improved Sanitation (% of hh) sample size  \
# 446                                      168.0
# 445                                      214.0
# 443                                      216.0
# 442                                      408.0
# 439                                      192.0
# 451                                      336.0
# 447                                      238.0
# 448                                      576.0
# 452                                      551.0
# 440                                      576.0
#
#      Electricity in household (% of households)  \
# 446                                    1.919450
# 445                                    4.346860
# 443                                    3.234594
# 442                                    2.431695
# 439                                    4.654329
# 451                                   11.376094
# 447                                    2.709589
# 448                                   12.933432
# 452                                   11.173716
# 440                                   34.434784
#
#      Electricity (% of hh) standard error  Electricity (% of hh) sample size  \
# 446                              1.124550                              168.0
# 445                              1.419100                              216.0
# 443                              1.199603                              216.0
# 442                              0.772978                              403.0
# 439                              1.372487                              191.0
# 451                              1.327883                              335.0
# 447                              0.885167                              238.0
# 448                              1.072103                              574.0
# 452                              1.068031                              552.0
# 440                              1.846845                              575.0
#
#      Radio in household (% of households)  Radio (% of hh) standard error  \
# 446                              3.043058                        1.346671
# 445                             14.614330                        2.398808
# 443                             37.948437                        3.189324
# 442                             22.823439                        1.742535
# 439                             10.072643                        1.884186
# 451                             34.194244                        2.175112
# 447                             24.821198                        2.640155
# 448                             37.873619                        1.873013
# 452                             34.686218                        1.791120
# 440                             68.935432                        1.851601
#
#      Radio (% of hh) sample size  Television in household (% of households)  \
# 446                        168.0                                   0.000000
# 445                        215.0                                   0.442941
# 443                        216.0                                   0.000000
# 442                        408.0                                   1.620440
# 439                        191.0                                   0.000000
# 451                        336.0                                   3.122821
# 447                        238.0                                   0.338699
# 448                        572.0                                   3.611712
# 452                        551.0                                   3.994729
# 440                        573.0                                  14.285715
#
#      Television (% of hh) standard error  Television (% of hh) sample size  \
# 446                             0.000000                             168.0
# 445                             0.442942                             216.0
# 443                             0.000000                             216.0
# 442                             0.611728                             408.0
# 439                             0.000000                             192.0
# 451                             0.957105                             336.0
# 447                             0.338699                             238.0
# 448                             0.691892                             573.0
# 452                             0.779097                             551.0
# 440                             1.426356                             574.0
#
#      Radio and/or television in household (% of households)  \
# 446                                           3.043058
# 445                                          14.992538
# 443                                          37.948437
# 442                                          23.363586
# 439                                          10.021016
# 451                                          34.194244
# 447                                          24.821198
# 448                                          38.154705
# 452                                          34.827644
# 440                                          70.138893
#
#      Radio and/or TV (% of hh) standard error  \
# 446                                  1.346671
# 445                                  2.407587
# 443                                  3.189324
# 442                                  1.720557
# 439                                  1.874529
# 451                                  2.175112
# 447                                  2.640155
# 448                                  1.872523
# 452                                  1.783716
# 440                                  1.819409
#
#      Radio and/or TV (% of hh) sample size
# 446                                  168.0
# 445                                  216.0
# 443                                  216.0
# 442                                  408.0
# 439                                  192.0
# 451                                  336.0
# 447                                  238.0
# 448                                  576.0
# 452                                  552.0
# 440                                  576.0

# %% [markdown]
# # Modelling and Prediction

# %%
df.head()
# Out:
#   Country name ISO code  ISO numeric code Subnational region name  \
# 0      Burundi      BDI             108.0                 Bubanza
# 1      Burundi      BDI             108.0        Bujumbura Mairie
# 2      Burundi      BDI             108.0         Bujumbura Rural
# 3      Burundi      BDI             108.0                  Bururi
# 4      Burundi      BDI             108.0                 Cankuzo
#
#    CCAPS subnational region ID    Year Data Source             Website  \
# 0                     108002.0  2011.0         DHS  www.measuredhs.com
# 1                     108003.0  2011.0         DHS  www.measuredhs.com
# 2                     108004.0  2011.0         DHS  www.measuredhs.com
# 3                     108005.0  2011.0         DHS  www.measuredhs.com
# 4                     108006.0  2011.0         DHS  www.measuredhs.com
#
#    Net primary attendance rate (%)  Primary NAR standard error  \
# 0                        62.212669                    1.541257
# 1                        75.802948                    1.635965
# 2                        62.212669                    1.541257
# 3                        66.308830                    1.372277
# 4                        61.176640                    1.455065
#
#    Primary NAR sample size  Gross primary attendance rate (%)  \
# 0                   1494.0                         102.472580
# 1                    718.0                         112.636269
# 2                   1494.0                         102.472580
# 3                   2036.0                         117.472328
# 4                   2213.0                         113.127411
#
#    Primary GAR standard error  Primary GAR sample size  \
# 0                    3.636928                   1494.0
# 1                    4.013371                    719.0
# 2                    3.636928                   1494.0
# 3                    2.735463                   2037.0
# 4                    3.140667                   2216.0
#
#    Net secondary attendance rate (%)  Secondary NAR standard error  \
# 0                           7.844529                      0.965101
# 1                          31.958845                      2.921502
# 2                           7.844529                      0.965101
# 3                          12.385633                      1.100727
# 4                           5.808361                      0.836916
#
#    Secondar NAR sample size  Gross secondary attendance rate (%)  \
# 0                     817.0                            28.771719
# 1                     563.0                            95.412285
# 2                     817.0                            28.771719
# 3                    1268.0                            45.576622
# 4                    1438.0                            22.297937
#
#    Secondary GAR standard error  Secondary GAR sample size  \
# 0                      2.819628                      818.0
# 1                      6.530486                      563.0
# 2                      2.819628                      818.0
# 3                      3.021638                     1275.0
# 4                      2.037364                     1443.0
#
#    Access to improved water (% of population)  \
# 0                                   64.524750
# 1                                   90.069534
# 2                                   64.524750
# 3                                   67.941315
# 4                                   78.772392
#
#    Improved Water (% of pop) standard error  \
# 0                                  4.098234
# 1                                  2.291323
# 2                                  4.098234
# 3                                  3.748927
# 4                                  2.694942
#
#    Improved Water (% of pop) sample size  \
# 0                                 7248.0
# 1                                 4752.0
# 2                                 7248.0
# 3                                 9731.0
# 4                                11487.0
#
#    Access to improved sanitation (% of population)  \
# 0                                        42.428234
# 1                                        86.296799
# 2                                        42.428234
# 3                                        55.417877
# 4                                        44.918869
#
#    Improved Sanitation (% of pop) standard error  \
# 0                                       5.014913
# 1                                       4.456155
# 2                                       5.014913
# 3                                       4.216816
# 4                                       3.165077
#
#    Improved Sanitation (% of pop) sample size  \
# 0                                      7248.0
# 1                                      4752.0
# 2                                      7248.0
# 3                                      9731.0
# 4                                     11487.0
#
#    Electricity in household (% of population)  \
# 0                                    2.635628
# 1                                   62.607437
# 2                                    2.635628
# 3                                    3.004243
# 4                                    2.468756
#
#    Electricity (% of pop) standard error  Electricity (% of pop) sample size  \
# 0                               0.943304                              7248.0
# 1                               6.168787                              4752.0
# 2                               0.943304                              7248.0
# 3                               0.774846                              9731.0
# 4                               0.734672                             11487.0
#
#    Radio in household (% of population)  Radio (% of pop) standard error  \
# 0                             55.748539                         2.021995
# 1                             80.243233                         2.606479
# 2                             55.748539                         2.021995
# 3                             56.422264                         1.242099
# 4                             56.779015                         1.442348
#
#    Radio (% of pop) sample size  Television in household (% of population)  \
# 0                        7248.0                                   1.855816
# 1                        4752.0                                  53.190296
# 2                        7248.0                                   1.855816
# 3                        9731.0                                   4.437777
# 4                       11487.0                                   1.720605
#
#    Television (% of pop) standard error  Television (% of pop) sample size  \
# 0                              0.639537                             7248.0
# 1                              5.902191                             4752.0
# 2                              0.639537                             7248.0
# 3                              2.226572                             9731.0
# 4                              0.525061                            11487.0
#
#    Radio and/or Television in household (% of population)  \
# 0                                          55.494587
# 1                                          81.972755
# 2                                          55.494587
# 3                                          56.785858
# 4                                          56.796986
#
#    Radio and/or TV (% of pop) standard error  \
# 0                                   2.013759
# 1                                   2.609640
# 2                                   2.013759
# 3                                   1.242379
# 4                                   1.442665
#
#    Radio and/or TV (% of pop) sample size  \
# 0                                  7248.0
# 1                                  4752.0
# 2                                  7248.0
# 3                                  9731.0
# 4                                 11487.0
#
#    Access to improved water (% of households)  \
# 0                                   64.727745
# 1                                   88.540581
# 2                                   64.727745
# 3                                   67.956390
# 4                                   77.699234
#
#    Improved Water (% of hh) standard error  \
# 0                                 4.048388
# 1                                 2.479091
# 2                                 4.048388
# 3                                 3.516714
# 4                                 2.894140
#
#    Improved Water (% of hh) sample size  \
# 0                                1441.0
# 1                                 912.0
# 2                                1441.0
# 3                                1921.0
# 4                                2405.0
#
#    Access to improved sanitation (% of households)  \
# 0                                        41.207016
# 1                                        85.660011
# 2                                        41.207016
# 3                                        54.182552
# 4                                        43.863773
#
#    Improved Sanitation (% of hh) standard error  \
# 0                                      4.939431
# 1                                      4.584234
# 2                                      4.939431
# 3                                      4.030688
# 4                                      3.031380
#
#    Improved Sanitation (% of hh) sample size  \
# 0                                     1441.0
# 1                                      912.0
# 2                                     1441.0
# 3                                     1921.0
# 4                                     2405.0
#
#    Electricity in household (% of households)  \
# 0                                    2.563438
# 1                                   57.100666
# 2                                    2.563438
# 3                                    2.655414
# 4                                    2.015260
#
#    Electricity (% of hh) standard error  Electricity (% of hh) sample size  \
# 0                              0.932698                             1441.0
# 1                              6.255036                              912.0
# 2                              0.932698                             1441.0
# 3                              0.686601                             1921.0
# 4                              0.615241                             2405.0
#
#    Radio in household (% of households)  Radio (% of hh) standard error  \
# 0                             50.203342                        1.984068
# 1                             75.303909                        2.757758
# 2                             50.203342                        1.984068
# 3                             51.190273                        1.153134
# 4                             51.336479                        1.450344
#
#    Radio (% of hh) sample size  Television in household (% of households)  \
# 0                       1441.0                                   1.656027
# 1                        912.0                                  44.327900
# 2                       1441.0                                   1.656027
# 3                       1921.0                                   3.321293
# 4                       2405.0                                   1.289977
#
#    Television (% of hh) standard error  Television (% of hh) sample size  \
# 0                             0.644799                            1441.0
# 1                             5.504890                             912.0
# 2                             0.644799                            1441.0
# 3                             1.444279                            1921.0
# 4                             0.369800                            2405.0
#
#    Radio and/or television in household (% of households)  \
# 0                                          49.767658
# 1                                          77.148560
# 2                                          49.767658
# 3                                          51.439995
# 4                                          51.364285
#
#    Radio and/or TV (% of hh) standard error  \
# 0                                  1.906297
# 1                                  2.845784
# 2                                  1.906297
# 3                                  1.158005
# 4                                  1.450414
#
#    Radio and/or TV (% of hh) sample size
# 0                                 1441.0
# 1                                  912.0
# 2                                 1441.0
# 3                                 1921.0
# 4                                 2405.0

# %%
# Dropping specified columns
df = df.drop(columns=['Country name', 'ISO code', 'ISO numeric code', 'CCAPS subnational region ID', 'Data Source', 'Website'])

# Encoding 'Subnational region name' using pandas get_dummies
df_encoded = pd.get_dummies(df, columns=['Subnational region name'])

# Separating features and targets for the attendance rate columns
features = df_encoded.drop(columns=[
    'Net primary attendance rate (%)',
    'Gross primary attendance rate (%)',
    'Net secondary attendance rate (%)',
    'Gross secondary attendance rate (%)'
])

# The target variables are the attendance rates
targets = df_encoded[
    ['Net primary attendance rate (%)',
     'Gross primary attendance rate (%)',
     'Net secondary attendance rate (%)',
     'Gross secondary attendance rate (%)']
]

# Splitting the dataset into training and test sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.2, random_state=42)

# Using two different models for the prediction: Linear Regression and Random Forest Regression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Initializing models
lr = LinearRegression()
rf = RandomForestRegressor(n_estimators=100, random_state=42)

# Dictionary to store models and their results
models = {'Linear Regression': lr, 'Random Forest': rf}
results = {}

# Training and evaluating models
for name, model in models.items():
    # Train each model
    model.fit(X_train, y_train)
    # Predict on test set
    y_pred = model.predict(X_test)
    # Calculate the mean squared error for each target variable
    mse = mean_squared_error(y_test, y_pred, multioutput='raw_values')
    results[name] = mse

results_df = pd.DataFrame(results, index=[
    'Net primary attendance rate (%)',
    'Gross primary attendance rate (%)',
    'Net secondary attendance rate (%)',
    'Gross secondary attendance rate (%)'
])

results_df
# Out:
#                                      Linear Regression  Random Forest
# Net primary attendance rate (%)             390.450517     138.508747
# Gross primary attendance rate (%)           756.537136     311.037505
# Net secondary attendance rate (%)           136.998578      68.767067
# Gross secondary attendance rate (%)         290.465984     195.367837

# %%
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor

# Initializing additional complex models
svr = SVR(kernel='rbf')
knn = KNeighborsRegressor(n_neighbors=5)
xgb = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# Dictionary to store additional models
additional_models = {
    'Support Vector Regression': svr,
    'K-Nearest Neighbors Regression': knn,
    'XGBoost Regression': xgb
}

# Initialize dictionaries to store results
mse_results_cleaned = {}
mae_results_cleaned = {}
r2_results_cleaned = {}

# Training and evaluating additional models for each column in y_train and y_test
for name, model in additional_models.items():
    mse_results_col = {}  # Dictionary to store MSE for each target variable
    mae_results_col = {}  # Dictionary to store MAE for each target variable
    r2_results_col = {}   # Dictionary to store R-squared for each target variable
    for col in y_train.columns:
        y_train_col = y_train[col]
        y_test_col = y_test[col]
        # Train each model for the current column
        model.fit(X_train, y_train_col)
        # Predict on test set for the current column
        y_pred = model.predict(X_test)
        # Calculate the R-squared value for the current column
        r2 = r2_score(y_test_col, y_pred)
        # Calculate the Mean Squared Error for the current column
        mse = mean_squared_error(y_test_col, y_pred)
        # Calculate the Mean Absolute Error for the current column
        mae = mean_absolute_error(y_test_col, y_pred)
        # Storing results for the current column
        mse_results_col[col] = mse
        mae_results_col[col] = mae
        r2_results_col[col] = r2
    # Storing results for the current model
    mse_results_cleaned[name] = mse_results_col
    mae_results_cleaned[name] = mae_results_col
    r2_results_cleaned[name] = r2_results_col

# Display results for all models and target variables
print("Mean Squared Error Results:")
print(mse_results_cleaned)
print("\nMean Absolute Error Results:")
print(mae_results_cleaned)
print("\nR-squared Results:")
print(r2_results_cleaned)
# Out:
# Mean Squared Error Results:
# {'Support Vector Regression': {'Net primary attendance rate (%)': 586.3823932902854, 'Gross primary attendance rate (%)': 948.300888967892, 'Net secondary attendance rate (%)': 471.51403098972816, 'Gross secondary attendance rate (%)': 922.1880847128164}, 'K-Nearest Neighbors Regression': {'Net primary attendance rate (%)': 361.3116137353286, 'Gross primary attendance rate (%)': 670.9060060008967, 'Net secondary attendance rate (%)': 319.6698480193707, 'Gross secondary attendance rate (%)': 637.2724138752549}, 'XGBoost Regression': {'Net primary attendance rate (%)': 138.36299451354324, 'Gross primary attendance rate (%)': 238.08556090643512, 'Net secondary attendance rate (%)': 65.16007363608966, 'Gross secondary attendance rate (%)': 259.393468707274}}
#
# Mean Absolute Error Results:
# {'Support Vector Regression': {'Net primary attendance rate (%)': 17.569232820795197, 'Gross primary attendance rate (%)': 22.909561458655805, 'Net secondary attendance rate (%)': 16.465996872410617, 'Gross secondary attendance rate (%)': 23.19936389242117}, 'K-Nearest Neighbors Regression': {'Net primary attendance rate (%)': 14.340913321748694, 'Gross primary attendance rate (%)': 19.054971359465448, 'Net secondary attendance rate (%)': 12.524067290501794, 'Gross secondary attendance rate (%)': 18.322891024350326}, 'XGBoost Regression': {'Net primary attendance rate (%)': 6.305303724188554, 'Gross primary attendance rate (%)': 9.32085465882954, 'Net secondary attendance rate (%)': 5.206873233694779, 'Gross secondary attendance rate (%)': 9.947774420600188}}
#
# R-squared Results:
# {'Support Vector Regression': {'Net primary attendance rate (%)': -0.12498076404522207, 'Gross primary attendance rate (%)': -0.0020001527964887966, 'Net secondary attendance rate (%)': -0.09937158750704911, 'Gross secondary attendance rate (%)': -0.11896993634436392}, 'K-Nearest Neighbors Regression': {'Net primary attendance rate (%)': 0.3068198842096509, 'Gross primary attendance rate (%)': 0.29110272030152884, 'Net secondary attendance rate (%)': 0.2546649193927196, 'Gross secondary attendance rate (%)': 0.22674269575920625}, 'XGBoost Regression': {'Net primary attendance rate (%)': 0.7345491456351176, 'Gross primary attendance rate (%)': 0.7484324108706355, 'Net secondary attendance rate (%)': 0.8480742270913574, 'Gross secondary attendance rate (%)': 0.6852556458068837}}

# %% [markdown]
# 1. Mean Squared Error (MSE) Results:
#
#   For each model, MSE values are provided for each of the four target variables. MSE measures the average squared difference between the predicted values and the actual values. Lower MSE values indicate a better fit of the model to the data. In this case, XGBoost Regression has the lowest MSE values for all target variables, indicating the best performance in terms of reducing squared errors.
#
# 2. Mean Absolute Error (MAE) Results:
#
#   Similar to MSE, MAE values are provided for each model and target variable. MAE measures the average absolute difference between the predicted and actual values. Lower MAE values indicate a better fit of the model to the data. Once again, XGBoost Regression has the lowest MAE values for all target variables, demonstrating its effectiveness in reducing absolute errors.
#
# 3. R-squared (R2) Results:
#
#   R2 values represent the proportion of the variance in the dependent variable that is predictable from the independent variables. R2 values range from -1 to 1, where a higher R2 indicates a better fit of the model. In this analysis, XGBoost Regression has the highest R2 values for all target variables, indicating that it explains a significant portion of the variance in the data. Support Vector Regression generally has negative R2 values, which suggest that it may not fit the data well.
#
# In summary, based on these results, XGBoost Regression appears to be the most effective model among the three for predicting the specified target variables, as it has the lowest MSE and MAE values and the highest R2 values. Support Vector Regression seems to perform the least effectively in this context, as it has relatively high MSE and MAE values and negative R2 values for most target variables.
