# %%
import pandas as pds

pds

#Pandas can read files in HTML, JSON, CSV and even from database or google drive
#It can also cave to them to.
# Out:
# <module 'pandas' from 'C:\\Users\\DELL\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
import numpy as npy

npy

#THe numpy  module is used to handle dimentional array
# Out:
# <module 'numpy' from 'C:\\Users\\DELL\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\numpy\\__init__.py'>

# %%
readData = pds.read_csv('data.csv') #Using the read_csv method, i just read a csv file 

readData
# Out:
#       x          y
# 0    24  21.549452
# 1    50  47.464463
# 2    15  17.218656
# 3    38  36.586398
# 4    87  87.288984
# ..   ..        ...
# 140  56  59.162366
# 141  80  75.241484
# 142  26  28.223258
# 143  25  25.333237
# 144   8   6.364616
#
# [145 rows x 2 columns]

# %%
#Accessing the y column from the dataset inported and saving only the column to the varible readDataY 
readDataY = readData[['y']]

readDataY
# Out:
#              y
# 0    21.549452
# 1    47.464463
# 2    17.218656
# 3    36.586398
# 4    87.288984
# ..         ...
# 140  59.162366
# 141  75.241484
# 142  28.223258
# 143  25.333237
# 144   6.364616
#
# [145 rows x 1 columns]

# %%
#Accessing the x column from the dataset imported and saving only the column to the varible readDataX 
readDataX = readData[['x']]

readDataX
# Out:
#       x
# 0    24
# 1    50
# 2    15
# 3    38
# 4    87
# ..   ..
# 140  56
# 141  80
# 142  26
# 143  25
# 144   8
#
# [145 rows x 1 columns]

# %%
readDataY[['y']].to_csv('saveCSVDataY.csv')

readDataY
# Out:
#              y
# 0    21.549452
# 1    47.464463
# 2    17.218656
# 3    36.586398
# 4    87.288984
# ..         ...
# 140  59.162366
# 141  75.241484
# 142  28.223258
# 143  25.333237
# 144   6.364616
#
# [145 rows x 1 columns]

# %%
readDataX[['x']].to_csv('saveCSVDataX.csv')

readDataX
# Out:
#       x
# 0    24
# 1    50
# 2    15
# 3    38
# 4    87
# ..   ..
# 140  56
# 141  80
# 142  26
# 143  25
# 144   8
#
# [145 rows x 1 columns]

# %%
readExcelData = pds.read_excel('data.xlsx')

readExcelData
# Out:
#       x          y
# 0    24  21.549452
# 1    50  47.464463
# 2    15  17.218656
# 3    38  36.586398
# 4    87  87.288984
# ..   ..        ...
# 140  56  59.162366
# 141  80  75.241484
# 142  26  28.223258
# 143  25  25.333237
# 144   8   6.364616
#
# [145 rows x 2 columns]

# %%
#Saving the extracted file to excel
readExcelDataX = readExcelData[['x']]

readExcelDataX

#FOr this module to run, some module is needed to be installed,
# pip install xlrd
# pip install openpyxl #This is testing and worked fine this this case
# Note: you dont need to import them.
# Out:
#       x
# 0    24
# 1    50
# 2    15
# 3    38
# 4    87
# ..   ..
# 140  56
# 141  80
# 142  26
# 143  25
# 144   8
#
# [145 rows x 1 columns]

# %%
'''try:
    readExcelData[['x']].to_excel('saveExcelDataX.xlsx')
    pds.read_excel('saveExcelDataX.xlsx')
except SyntaxError:
    readExcelData[['x']].to_excel('saveExcelDataX.xlsx')'''
# Out:
# "try:\n    readExcelData[['x']].to_excel('saveExcelDataX.xlsx')\n    pds.read_excel('saveExcelDataX.xlsx')\nexcept SyntaxError:\n    readExcelData[['x']].to_excel('saveExcelDataX.xlsx')"

# %%
readExcelData[['x']].to_excel('saveExcelDataX.xlsx')
pds.read_excel('saveExcelDataX.xlsx')
# Out:
#      Unnamed: 0   x
# 0             0  24
# 1             1  50
# 2             2  15
# 3             3  38
# 4             4  87
# ..          ...  ..
# 140         140  56
# 141         141  80
# 142         142  26
# 143         143  25
# 144         144   8
#
# [145 rows x 2 columns]

# %%
readExcelData[['y']].to_excel('saveExcelDataY.xlsx')
pds.read_excel('saveExcelDataY.xlsx')
# Out:
#      Unnamed: 0          y
# 0             0  21.549452
# 1             1  47.464463
# 2             2  17.218656
# 3             3  36.586398
# 4             4  87.288984
# ..          ...        ...
# 140         140  59.162366
# 141         141  75.241484
# 142         142  28.223258
# 143         143  25.333237
# 144         144   6.364616
#
# [145 rows x 2 columns]

# %%
#url = 'https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
url = 'fuel_ferc1.csv' #THis works locally

#fuel_data = pds.read_csv(url, error_bad_lines=False)

#From my research the error_bad_lines parameter has been Deprecated since version 1.3.0
#SO, alterntive is to use the on_bad_lines paramter

fuel_data = pds.read_csv(url)
fuel_data
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
#To give a description of the data 
fuel_data.describe(include = 'all') #'all' : All columns of the input will be included in the output.
# Out:
#                     record_id  utility_id_ferc1   report_year  \
# count                   29523      29523.000000  29523.000000
# unique                  29523               NaN           NaN
# top     f1_fuel_1994_12_1_0_7               NaN           NaN
# freq                        1               NaN           NaN
# mean                      NaN        118.601836   2005.806050
# std                       NaN         74.178353      7.025483
# min                       NaN          1.000000   1994.000000
# 25%                       NaN         55.000000   2000.000000
# 50%                       NaN        122.000000   2006.000000
# 75%                       NaN        176.000000   2012.000000
# max                       NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29343     2.952300e+04
# unique             2315                   6         9              NaN
# ...

# %%
fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
# A dataframe can be easily categorised into different
# segments based on a given criteria using the groupby() function.

# This initially splits the dataframe into the groups then applies 
# a function to the groups after which the results are combined.

fuel_data.groupby('fuel_unit')['fuel_unit'].count()

#Whay=t this is going to do is that, it 
#group the data in the dataset base on the value of fule unit for every id.
#Since we notice that after summing the total emppty spaces from the using .isnull.sum, 
#After summign we notice that the data had 180 empty cell under the fuel_unit column.
# So here, we now group it base on all possible value in fuel_unit column
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
#To be sure fit the null cell is 180, lets doe somethign here :)

#Since the descrieb told use we have 29523 rows
#lets print the number of cell with content the fuel_unit row 

fuel_data['fuel_unit'].count().sum()
# Out:
# 29343

# %%
#Now resultis  29343, meaning 29343 has content.

print(29523 - 29343)
# Out:
# 180

# %%
# As seen we have 180, meaning 180 cells has nothing under the fuel_data cell

#Now lets fill those 180 empty cell with whats already in some filled columns

fuel_data[['fuel_unit']] = fuel_data[['fuel_unit']].fillna(value='mcf')

# %%
#Now, after doing that, lets check if our null cell has been filled with mcf as assigned in the last cell

fuel_data.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
#Now, our data have no null of empty cell.
fuel_data
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fuel_data.groupby('report_year')['report_year'].count()

# This is going to group the report_year column by the parameter (i.e year).
# Then print the year and the numbers of times it apears.
# Out:
# report_year
# 1994    1235
# 1995    1201
# 1996    1088
# 1997    1094
# 1998    1107
# 1999    1050
# 2000    1373
# 2001    1356
# 2002    1205
# 2003    1211
# 2004    1192
# 2005    1269
# 2006    1243
# 2007    1264
# 2008    1228
# 2009    1222
# 2010    1261
# 2011    1240
# 2012    1243
# 2013    1199
# 2014    1171
# 2015    1093
# 2016    1034
# 2017     993
# 2018     951
# Name: report_year, dtype: int64

# %%
fuel_data.groupby('fuel_type_code_pudl').first()

#THis group the column  fuel_type_code_pudl column using the groupby function
# It then use the first() to print out the first entries in all of the group formed
# Out:
#                                   record_id  utility_id_ferc1  report_year  \
# fuel_type_code_pudl
# coal                  f1_fuel_1994_12_1_0_7                 1         1994
# gas                  f1_fuel_1994_12_2_0_10                 2         1994
# nuclear               f1_fuel_1994_12_2_1_1                 2         1994
# oil                   f1_fuel_1994_12_6_0_2                 6         1994
# other                f1_fuel_1994_12_11_0_6                11         1994
# waste                 f1_fuel_1994_12_9_0_3                 9         1994
#
#                      plant_name_ferc1 fuel_unit  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                         rockport       ton        5377489.0
# gas                         chickasaw       mcf          40533.0
# nuclear              joseph m. farley       kgU           2260.0
# oil                      clinch river       bbl           6510.0
# other                      w.f. wyman       bbl          55652.0
# ...

# %%
fuel_df1 = fuel_data.iloc[0:19000].reset_index(drop=True) 
#NB: iloc uses the n-1 rule, its an index
#THe iloc index the data from 0 to 19,0000

#THe parameter drop = True takes boolean and resets the index to the default integer index if it = True. 
fuel_df1
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 4        f1_fuel_1994_12_2_0_10                 2         1994
# ...                         ...               ...          ...
# 18995   f1_fuel_2009_12_182_1_9               182         2009
# 18996  f1_fuel_2009_12_182_1_10               182         2009
# 18997  f1_fuel_2009_12_182_1_13               182         2009
# 18998  f1_fuel_2009_12_182_1_14               182         2009
# 18999    f1_fuel_2009_12_79_0_1                79         2009
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fuel_df2 = fuel_data.iloc[19000:].reset_index(drop=True)
#This does same as above, but here, pickes the data from index 19000

fuel_df2
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0       f1_fuel_2009_12_79_0_2                79         2009
# 1       f1_fuel_2009_12_79_0_4                79         2009
# 2       f1_fuel_2009_12_79_0_5                79         2009
# 3       f1_fuel_2009_12_79_0_7                79         2009
# 4      f1_fuel_2009_12_79_0_10                79         2009
# ...                        ...               ...          ...
# 10518  f1_fuel_2018_12_12_0_13                12         2018
# 10519   f1_fuel_2018_12_12_1_1                12         2018
# 10520  f1_fuel_2018_12_12_1_10                12         2018
# 10521  f1_fuel_2018_12_12_1_13                12         2018
# 10522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  montrose                 oil       bbl          22912.0
# ...

# %%
assert len(fuel_data) == (len(fuel_df1) + len(fuel_df2))

#Doesnt raise an Assertion Error because the condtional statement corrrect

# %%
print(help('assert')) #Remember assert is a keyword
#THis briefly print for us how to use it
# Out:
# The "assert" statement
# **********************
#
# Assert statements are a convenient way to insert debugging assertions
# into a program:
#
#    assert_stmt ::= "assert" expression ["," expression]
#
# The simple form, "assert expression", is equivalent to
#
#    if __debug__:
#        if not expression: raise AssertionError
#
# The extended form, "assert expression1, expression2", is equivalent to
#
#    if __debug__:
#        if not expression1: raise AssertionError(expression2)
#
# These equivalences assume that "__debug__" and "AssertionError" refer
# to the built-in variables with those names.  In the current
# implementation, the built-in variable "__debug__" is "True" under
# normal circumstances, "False" when optimization is requested (command
# line option "-O").  The current code generator emits no code for an
# assert statement when optimization is requested at compile time.  Note
# that it is unnecessary to include the source code for the expression
# ...

# %%
'''Merging in Pandas can be likened to join operations in relational databases like SQL. 
Left, inner, right and outer are the merging methods available to the merge() function. 
The left method can be likened to SQL left outer join,  inner to  SQL inner join,
right to SQL right outer join and outer to SQL full outer join. In our analysis,
we split the fuel data into two groups and merge using different methods.'''
# Out:
# 'Merging in Pandas can be likened to join operations in relational databases like SQL. \nLeft, inner, right and outer are the merging methods available to the merge() function. \nThe left method can be likened to SQL left outer join,  inner to  SQL inner join,\nright to SQL right outer join and outer to SQL full outer join. In our analysis,\nwe split the fuel data into two groups and merge using different methods.'

# %%
Fuel_data_mergeI = pds.merge(fuel_df1, fuel_df2, how='inner')
#If how isnt passed, its INNER DEFFAULY
#Here, fuel_df1 = left
# and fuel_df2 - right
#The inner set is the, use intersection of keys from both frames, similar to intersect of sets in maths or  a SQL inner
# So, an inner merge will lose rows that do not match in both dataframes.
Fuel_data_mergeI

#Why it doesnt return anything is becuause both dataframes have same same head and therefore their intersection is none
# Out:
# Empty DataFrame
# Columns: [record_id, utility_id_ferc1, report_year, plant_name_ferc1, fuel_type_code_pudl, fuel_unit, fuel_qty_burned, fuel_mmbtu_per_unit, fuel_cost_per_unit_burned, fuel_cost_per_unit_delivered, fuel_cost_per_mmbtu]
# Index: []

# %%
Fuel_data_mergeO = pds.merge(fuel_df1, fuel_df2, how='outer')

Fuel_data_mergeO

#Now the how being outer means that union, like in math set, it should combine all posible key from both fram
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
Fuel_data_mergeL = pds.merge(fuel_df1, fuel_df2, how='left')

Fuel_data_mergeL

#Using the left as the value of the how parameter
#Recall, we condsider the first parameter (in this case fuel_df1) as the left dataframe
# and the second parameter as the right dataframe

#So, using the left removes rows from the right dataframe that do not have a match with the left dataframe.
#i.e any row thats in the left dataframe and not in the right dataframe is not returned
#but rather, only row in the left and rows in right thats also in left is returned

#if i change the left to right, the opposite happens.
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 4        f1_fuel_1994_12_2_0_10                 2         1994
# ...                         ...               ...          ...
# 18995   f1_fuel_2009_12_182_1_9               182         2009
# 18996  f1_fuel_2009_12_182_1_10               182         2009
# 18997  f1_fuel_2009_12_182_1_13               182         2009
# 18998  f1_fuel_2009_12_182_1_14               182         2009
# 18999    f1_fuel_2009_12_79_0_1                79         2009
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
# Concatenation is performed with the concat() function 
# It's done by combining series or dataframes while keeping the indices 
# of the individual unit irrespective of duplicate indices. 
# In the notebook, we created a dummy dataframe data_to_concat which we
# concatenated to the fuel_data as below:
data_to_concat = pds.read_csv('data_to_concat.csv')
concat_data = pds.concat([fuel_data , data_to_concat]).reset_index(drop = True)

concat_data
# Out:
#                     record_id  utility_id_ferc1  report_year  \
# 0       f1_fuel_1994_12_1_0_7               1.0       1994.0
# 1      f1_fuel_1994_12_1_0_10               1.0       1994.0
# 2       f1_fuel_1994_12_2_0_1               2.0       1994.0
# 3       f1_fuel_1994_12_2_0_7               2.0       1994.0
# 4      f1_fuel_1994_12_2_0_10               2.0       1994.0
# ...                       ...               ...          ...
# 29663                     NaN               NaN          NaN
# 29664                     NaN               NaN          NaN
# 29665                     NaN               NaN          NaN
# 29666                     NaN               NaN          NaN
# 29667                     NaN               NaN          NaN
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# 1      rockport total plant                coal       ton       10486945.0
# ...

# %%
# As seeon both dataset has been joined together in one dataframe.
# TO sbe sure, the numbers of rows has increased from 29523 to 296698.
# Also, the number of columns as increased from 11 to 13. 

# to have a full view of the concatenated dataframe lets see its transpose

concat_data.T
# Out:
#                                               0                       1      \
# record_id                     f1_fuel_1994_12_1_0_7  f1_fuel_1994_12_1_0_10
# utility_id_ferc1                                1.0                     1.0
# report_year                                  1994.0                  1994.0
# plant_name_ferc1                           rockport    rockport total plant
# fuel_type_code_pudl                            coal                    coal
# fuel_unit                                       ton                     ton
# fuel_qty_burned                           5377489.0              10486945.0
# fuel_mmbtu_per_unit                           16.59                  16.592
# fuel_cost_per_unit_burned                     18.59                   18.58
# fuel_cost_per_unit_delivered                  18.53                   18.53
# fuel_cost_per_mmbtu                           1.121                    1.12
# ...

# %%
# Let save it so we can have a better isual view if opened in our excel.

concat_data.to_csv('concat_data.csv')
# SO from my view, i noticed the concatenation is done such that the first dataframe in the concat function is in the normal position 
# then the second concatenated file is added to it, not at the buttom directly
# But, after all of the row and column of the first dataset.
# i.e after the last rom of the first dataset, the concatenation begins
# also, after the last column of the first dataset, the concatenation begins. 
# WIth that, it made it such that the concatenated dataset is started by the egde of the first dataset.

# %%
# Beacause duplicated can affect the result of a data analysis,
# in, practice, removing duplicates are very important
# So, we use the duplicated function to remove the duplicate.
fuel_data.duplicated().sum()
# Out:
# 0

# %%
# Above, i have checked the sum of duplicated input in the dataset but its zero.
# However, we can still use it use used below

fuel_data.duplicated().any()
# Out:
# False

# %%
# WIth this All duplicate (if any) has been removed.

# %% [markdown]
# # NOW LETS DO SOME VISUALIZATION

# %%
# Import plotting library
import matplotlib.pyplot as plt #NB: plt isn't just alias to the matplotlib but the pyplot method in matplotlib.
#Bcause of that, when we want to us matplotlib for other things thats require a different method and not pyplot
#Its needed to import matplotlib on its own.

# %%
plt.figure(figsize=(7,4)) #The figure method Create a new figure, or activate an existing figure.
#The figsize parameter takes a tuple with 2 elements which can be int or float. it determines the size of the figure to be created in inches

plt.xticks(rotation=90) #Get or set the current tick locations and labels of the x-axis.
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %%
#Here is the dataset in the dictionary, unit and having a a list storing the element (variable)

fuel_unit = pds.DataFrame(
                        {'unit':['BBL', 'GAL', 'GRAMSU', 'KGU', 'MCF', 'MMBTU', 'MWDTH', 'MWHTH', 'TON'],
                         'count':[7998, 84, 464, 110, 11354, 180, 95, 100, 8958]})
fuel_unit
# Out:
#      unit  count
# 0     BBL   7998
# 1     GAL     84
# 2  GRAMSU    464
# 3     KGU    110
# 4     MCF  11354
# 5   MMBTU    180
# 6   MWDTH     95
# 7   MWHTH    100
# 8     TON   8958

# %%
sns.barplot(data=fuel_unit, x='unit', y='count')
#It takes 3 parameter, first the is the dateset variable, second the x-axis variabel, third the y-axis variable

plt.xlabel('Fuel Unit')
#Because of the extreme range of t
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 sns.barplot(data=fuel_unit, x='unit', y='count')
#       2 #It takes 3 parameter, first the is the dateset variable, second the x-axis variabel, third the y-axis variable
#       4 plt.xlabel('Fuel Unit')
#
# NameError: name 'sns' is not defined
